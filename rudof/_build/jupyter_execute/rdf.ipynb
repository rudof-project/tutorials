# %% [markdown]
# # RDF

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/<yourusername>/<yourrepo>/blob/main/book/notebooks/example.ipynb)

# %% [markdown]
# This document contains a short introduction to [RDF](https://www.w3.org/TR/rdf11-primer/) using [rudof](https://rudof-project.github.io/).

# %% [markdown]
# ## RDF as a data model

# %% [markdown]
# The library is available as `pyrudof`.

# %%
# !pip install pyrudof
# Out:
# Requirement already satisfied: pyrudof in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (0.1.120)

# %% [markdown]
# The main entry point if a class called `Rudof` through which most of the functionality is provided.

# %%
from pyrudof import Rudof, RudofConfig

# %% [markdown]
# In order to initialize that class, it is possible to pass a RudofConfig instance which contains configuration parameters for customization.

# %%
rudof = Rudof(RudofConfig())

# %% [markdown]
# ## Handling RDF data

# %%
rudof.read_data_str("""
prefix : <http://example.org/>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>

:x a :Person     ;
   :name "Alice" ;
   :knows :y     .
:y a :Person     ;
   :name "Bob"   ;
   :knows :z     .
:z a :Person     ;
   :knows :x     .
""")

# %% [markdown]
# The RDF data can easily be merged with other data.

# %%
rudof.read_data_str("""
prefix : <http://example.org/>
prefix xsd: <http://www.w3.org/2001/XMLSchema#>

:u a :Person     ;
   :name "Dave" ;
   :knows :y     .
:v a :Person     ;
   :name "Emily" ;
   :knows _:1    .
_:1 a :Person     ;
   :knows :x     .
""")

# %% [markdown]
# And the data can be serialized to different formats.

# %%
from pyrudof import RDFFormat
str = rudof.serialize_data(format=RDFFormat.NTriples)
print(str)
# Out:
# <http://example.org/y> <http://example.org/knows> <http://example.org/z> .
# <http://example.org/y> <http://example.org/name> "Bob" .
# <http://example.org/y> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.org/Person> .
# <http://example.org/z> <http://example.org/knows> <http://example.org/x> .
# <http://example.org/z> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.org/Person> .
# <http://example.org/v> <http://example.org/knows> _:1 .
# <http://example.org/v> <http://example.org/name> "Emily" .
# <http://example.org/v> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.org/Person> .
# <http://example.org/u> <http://example.org/knows> <http://example.org/y> .
# <http://example.org/u> <http://example.org/name> "Dave" .
# <http://example.org/u> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.org/Person> .
# <http://example.org/x> <http://example.org/knows> <http://example.org/y> .
# <http://example.org/x> <http://example.org/name> "Alice" .
# <http://example.org/x> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.org/Person> .
# _:1 <http://example.org/knows> <http://example.org/x> .
# _:1 <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://example.org/Person> .

# %% [markdown]
# ## Running SPARQL queries

# %%
from pyrudof import Rudof, RudofConfig, QuerySolutions
rudof = Rudof(RudofConfig())
rudof.reset_all()

# %%
rdf = """prefix : <http://example.org/>
:alice a :Person ;
 :name "Alice"   ;
 :knows :bob     .
:bob a :Person   ;
 :name "Robert"  .
"""
rudof.read_data_str(rdf)

# %%
query = """prefix : <http://example.org/>
select * where {
  # ?x a :Person
}
"""

results = rudof.run_query_str(query)

# %% [markdown]
# Show the results:

# %%
for result in iter(results):
    print(result.show())
# Out:
# ?x -> <http://example.org/alice>
#
# ?x -> <http://example.org/bob>

# %% [markdown]
# ## Validate using SHACL

# %%
# @title
rudof.reset_all()

# %% [markdown]
# Let's read some RDF data.

# %%
rudof.read_data_str("""
prefix : <http://example.org/>
prefix sh:     <http://www.w3.org/ns/shacl#>
prefix xsd:    <http://www.w3.org/2001/XMLSchema#>

:Person a sh:NodeShape;
   sh:targetNode :ok, :ko ;
   sh:property [
    sh:path     :name ;
    sh:minCount 1;
    sh:maxCount 1;
    sh:datatype xsd:string ;
  ] .
""")

# %%
rudof.read_data_str("""
prefix : <http://example.org/>

:ok :name "alice" .
:ko :name 1 .
""")

# %%
result = rudof.validate_shacl()

# %%
print(result.show())
# Out:
# 1 errors found
# sh:Violation node: :ko sh:datatype
# Datatype constraint not satisfied. Expected datatype: http://www.w3.org/2001/XMLSchema#string:name,_:e4897d0192380fb3fb5edd21ed1117121

# %% [markdown]
# The next command is just to clean the RDF data for the next examples.

# %%
rudof.reset_all()

# %% [markdown]
# ## Validate using ShEx

# %%
rudof.read_shex_str("""
prefix : <http://example.org/>
prefix xsd:    <http://www.w3.org/2001/XMLSchema#>

:Person {
 :name xsd:string
}
""")

# %%
rudof.read_data_str("""
prefix : <http://example.org/>

:ok :name "alice" .
:ko :name 1 .
""")

# %%
rudof.read_shapemap_str(":ok@:Person, :ko@:Person")

# %% [markdown]
# Once the ShEx schema and the Shapemap have been added to `rudof`, it is possible to validate the current RDF data with the `validate_shex()` method:

# %%
results = rudof.validate_shex()

# %% [markdown]
# `validate_shex()` returns a `ResultShapeMap` object which contains a `show()` method to show the results of the validation:

# %%
for (node, shape, status) in results.to_list():
    print(f"Node: {node.show()}")
    print(f"Shape: {shape.show()}")
    print(f"Conformant?: {status.is_conformant()}")
    print(f"Appinfo: {status.as_json()}")
    print("")
# Out:
# Node: http://example.org/ok
# Shape: http://example.org/Person
# Conformant?: True
# Appinfo: {'info': [{'reason': 'Shape passed. Node http://example.org/ok, shape 0: Shape  Preds: http://example.org/name, TripleExpr: RBE [C0], Keys: [http://example.org/name -> {C0}], conds: [C0 -> xsd:string], References: []'}], 'reason': 'Shape passed. Node :ok, shape 0: :Person = {:name xsd:string}\n', 'status': 'conformant'}
#
# Node: http://example.org/ko
# Shape: http://example.org/Person
# Conformant?: False
# Appinfo: {'info': [{'error': 'Datatype error: Datatype expected http://www.w3.org/2001/XMLSchema#string but found http://www.w3.org/2001/XMLSchema#integer for literal with lexical form 1'}], 'reason': 'Error Datatype error: Datatype expected http://www.w3.org/2001/XMLSchema#string but found http://www.w3.org/2001/XMLSchema#integer for literal with lexical form 1\n', 'status': 'nonconformant'}

# %% [markdown]
# We reset the status of the `ShEx` schema, the `Shapemap` and the current `RDF data` for the next section.

# %%
rudof.reset_all()

# %% [markdown]
# ## Converting ShEx to UML

# %% [markdown]
# `rudof` can be used to convert ShEx to diagrams in UML-like style. The converter generates a [PlantUML](https://plantuml.com/) string which can be written to a file and converted to an image using the PlantUML tool.

# %%
from pyrudof import UmlGenerationMode

# %%
rudof.read_shex_str("""
prefix : <http://example.org/>
prefix xsd:    <http://www.w3.org/2001/XMLSchema#>

:User {
 :name     xsd:string  ;
 :worksFor @:Company * ;
 :addres   @:Address   ;
 :knows    @:User
}

:Company {
  :name     xsd:string     ;
  :code     xsd:string     ;
  :employee @:User
}
:Address {
  :name     xsd:string ;
  :zip_code xsd:string
}
""")

# %%
plant_uml = rudof.shex2plantuml_file(UmlGenerationMode(), 'out.puml')

# %% [markdown]
# Now we install the PlantUML tools necessary to process the generated `plant_uml`

# %%
! pip install plantuml
# Out:
# Requirement already satisfied: plantuml in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (0.3.0)
# Requirement already satisfied: httplib2 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from plantuml) (0.31.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from httplib2->plantuml) (3.2.5)

# %%
! pip install ipython
# Out:
# Requirement already satisfied: ipython in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (9.6.0)
# Requirement already satisfied: decorator in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from jedi>=0.16->ipython) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from stack_data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in /home/labra/src/python/rudof/tutorials/.venv/lib/python3.12/site-packages (from stack_data->ipython) (0.2.3)

# %%
# !python -m plantuml out.puml
# Out:
# [{'filename': 'out.puml', 'gen_success': True}]

# %%
from IPython.display import Image

# %%
Image(f"out.png")

# %%
rudof.reset_all()

# %% [markdown]
# ## Converting DCTAP to ShEx

# %% [markdown]
# Rudof can be used to convert [DCTAP](https://www.dublincore.org/specifications/dctap/) files to ShEx.

# %% [markdown]
# DCTAP can be used to represent shapes using a tabular representation using CSV or an spreadsheet format like XLSX. As an example, the following CSV data:

# %%
dctap_str = """shapeId,propertyId,Mandatory,Repeatable,valueDatatype,valueShape
Person,name,true,false,xsd:string,
,birthdate,false,false,xsd:date,
,worksFor,false,true,,Company
Company,name,true,false,xsd:string,
,employee,false,true,,Person
"""

# %%
rudof.read_dctap_str(dctap_str)

# %%
dctap = rudof.get_dctap()

# %%
print(dctap)
# Out:
# Shape(Person)
#  name xsd:string
#  birthdate xsd:date ?
#  worksFor @Company *
# Shape(Company)
#  name xsd:string
#  employee @Person *

# %% [markdown]
# It is possible to convert the DCTAP obtained to ShEx

# %%
rudof.dctap2shex()

# %%
from pyrudof import ShExFormatter

# %%
shex = rudof.get_shex()

result = rudof.serialize_shex(shex, ShExFormatter())

# %%
print(result)
# Out:
# prefix sh: <http://www.w3.org/ns/shacl#>
# prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# prefix xsd: <http://www.w3.org/2001/XMLSchema#>
# prefix : <http://example.org/>
# prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# prefix dc: <http://purl.org/dc/elements/1.1/>
# :Person {
#     :name xsd:string;
#     :birthdate xsd:date ?;
#     :worksFor @:Company *
# }
# :Company {
#     :name xsd:string;
#     :employee @:Person *
# }

# %% [markdown]
# ## Support for RDF 1.2

# %% [markdown]
# Reset previous state of `rudof` and remnove the temporary file `out.puml` if it exists.

# %%
rudof.reset_all()

# %%
# !rm -f out.puml out.png

# %% [markdown]
# Rudof has added support for [RDF 1.2](https://www.w3.org/TR/rdf12-primer). It is possible, for example, to load some RDF 1.2 files and visualize them.

# %% [markdown]
# RDF 1.2 introduces [triple terms](https://www.w3.org/TR/rdf12-primer/#section-triple-terms) which denote statements that can be the object of some triples.
#
# For example, we can state that `:bob` is interested in `:MonaLisa` since `4th October 1998` using the following code:

# %%
rudof.read_data_str("""
 prefix : <http://example.org/>
 prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
 prefix xsd: <http://www.w3.org/2001/XMLSchema#>

 :aliceBelief a :Statement ;
    rdf:reifies <<( :bob :knows :dave  )>> ;
    :since 2025 ;
    :accordingTo :dave  .
 """)

# %%
uml = rudof.data2plantuml_file('out.puml')
# Out:
# Visual graph: VisualRDFGraph with 11 nodes and 4 edges
# Node 8: Iri: :bob (http://example.org/bob)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 1, as_object_in_triple: 0 }
# Node 2: Iri: :Statement (http://example.org/Statement)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 5: Predicate: :accordingTo (<http://example.org/accordingTo>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 6: Iri: :dave (http://example.org/dave)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 1 }
# Node 3: Predicate: :since (<http://example.org/since>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 1: Predicate: rdf:type (<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 0: Iri: :aliceBelief (http://example.org/aliceBelief)
#      count: UsageCount { as_predicate: 0, as_subject: 4, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 4: Literal: 2025
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 9: Predicate: :knows (<http://example.org/knows>)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 0, as_predicate_in_triple: 1, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 10: NonAssertedTriple
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 7: Reifies
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Edge reifies: 0 --> 10
# Edge :since (http://example.org/since): 0 --> 4
# Edge rdf:type (http://www.w3.org/1999/02/22-rdf-syntax-ns#type): 0 --> 2
# Edge :accordingTo (http://example.org/accordingTo): 0 --> 6
# Starting conversion...
# Converting node Iri: :bob (http://example.org/bob) with node id 8 to plantuml
# Converting node Iri: :Statement (http://example.org/Statement) with node id 2 to plantuml
# Converting node Predicate: :accordingTo (<http://example.org/accordingTo>) with node id 5 to plantuml
# Converting node Iri: :dave (http://example.org/dave) with node id 6 to plantuml
# Converting node Predicate: :since (<http://example.org/since>) with node id 3 to plantuml
# Converting node Predicate: rdf:type (<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>) with node id 1 to plantuml
# Converting node Iri: :aliceBelief (http://example.org/aliceBelief) with node id 0 to plantuml
# Converting node Literal: 2025 with node id 4 to plantuml
# Converting node Predicate: :knows (<http://example.org/knows>) with node id 9 to plantuml
# Converting node NonAssertedTriple with node id 10 to plantuml
# Converting node Reifies with node id 7 to plantuml

# %% [markdown]
# Convert the `puml` to an image.

# %%
# !python -m plantuml out.puml
# Out:
# [{'filename': 'out.puml', 'gen_success': True}]

# %%
Image(f"out.png")

# %% [markdown]
# In [RDF 1.2 turtle syntax](https://www.w3.org/TR/rdf12-turtle/), there are several possibilities to define triple terms.

# %% [markdown]
# ### Declaring triple terms directly

# %%
# !rm -f out.puml out.pnf
rudof.reset_all()

# %% [markdown]
# A triple term can be declared enclosing it between `<<(` and `)>>`. For example:

# %%
rudof.read_data_str("""
PREFIX :    <http://www.example.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

_:e38  :familyName                     "Smith" .
_:anno rdf:reifies <<( _:e38 :jobTitle "Designer" )>> .
_:anno :accordingTo                     :eric .
 """)

# %%
uml = rudof.data2plantuml_file('out.puml')
# Out:
# Visual graph: VisualRDFGraph with 10 nodes and 3 edges
# Node 9: NonAssertedTriple
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 3: BlankNode: anno
#      count: UsageCount { as_predicate: 0, as_subject: 2, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 0: BlankNode: e38
#      count: UsageCount { as_predicate: 0, as_subject: 1, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 1, as_object_in_triple: 0 }
# Node 1: Predicate: :familyName (<http://www.example.org/familyName>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 5: Iri: :eric (http://www.example.org/eric)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 2: Litera
# l: "Smith"
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 6: Reifies
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 4: Predicate: :accordingTo (<http://www.example.org/accordingTo>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 8: Literal: "Designer"
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 1 }
# Node 7: Predicate: :jobTitle (<http://www.example.org/jobTitle>)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 0, as_predicate_in_triple: 1, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Edge :familyName (http://www.example.org/familyName): 0 --> 2
# Edge :accordingTo (http://www.example.org/accordingTo): 3 --> 5
# Edge reifies: 3 --> 9
# Starting conversion...
# Converting node NonAssertedTriple with node id 9 to plantuml
# Converting node BlankNode: anno with node id 3 to plantuml
# Converting node BlankNode: e38 with node id 0 to plantuml
# Converting node Predicate: :familyName (<http://www.example.org/familyName>) with node id 1 to plantuml
# Converting node Iri: :eric (http://www.example.org/eric) with node id 5 to plantuml
# Converting node Literal: "Smith" with node id 2 to plantuml
# Converting node Reifies with node id 6 to plantuml
# Converting node Predicate: :accordingTo (<http://www.example.org/accordingTo>) with node id 4 to plantuml
# Converting node Literal: "Designer" with node id 8 to plantuml
# Converting node Predicate: :jobTitle (<http://www.example.org/jobTitle>) with node id 7 to plantuml

# %%
# !python -m plantuml out.puml
# Out:
# [{'filename': 'out.puml', 'gen_success': True}]

# %%
Image(f"out.png")

# %% [markdown]
# ### Reifying triples

# %%
# !rm -f out.puml out.pnf
rudof.reset_all()

# %% [markdown]
# Enclosing a triple between `<<` and `>>`, is a syntactic sugar that declares that there is a reifier whose object is that triple and that can be used to add more declarations about that reifier.
#
# For example:

# %%
rudof.read_data_str("""
 PREFIX :    <http://www.example.org/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

:employee38 :familyName "Smith" .
<< :employee38 :jobTitle "Assistant Designer" >> :accordingTo :employee22 .
 """)

# %%
uml = rudof.data2plantuml_file('out.puml')
# !python -m plantuml out.puml
Image(f"out.png")
# Out:
# Visual graph: VisualRDFGraph with 10 nodes and 3 edges
# Node 2: Literal: "Smith"
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 0: Iri: :employee38 (http://www.example.org/employee38)
#      count: UsageCount { as_predicate: 0, as_subject: 1, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 1, as_object_in_triple: 0 }
# Node 1: Predicate: :familyName (<http://www.example.org/familyName>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 3: BlankNode: aab516fb1df05bc24d9128e26f804fec
#      count: UsageCount { as_predicate: 0, as_subject: 2, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 4: Predicate: :accordingTo (<http://www.example.org/accordingTo>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 6: Reifies
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 9: NonAssertedTriple
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 5: Iri: :employee22 (http://www.example.org/employee22)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 8: Literal: "Assistant Designer"
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 1 }
# Node 7: Predicate: :jobTitle (<http://www.example.org/jobTitle>)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 0, as_predicate_in_triple: 1, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Edge reifies: 3 --> 9
# Edge :familyName (http://www.example.org/familyName): 0 --> 2
# Edge :accordingTo (http://www.example.org/accordingTo): 3 --> 5
# Starting conversion...
# Converting node Literal: "Smith" with node id 2 to plantuml
# Converting node Iri: :employee38 (http://www.example.org/employee38) with node id 0 to plantuml
# Converting node Predicate: :familyName (<http://www.example.org/familyName>) with node id 1 to plantuml
# Converting node BlankNode: aab516fb1df05bc24d9128e26f804fec with node id 3 to plantuml
# Converting node Predicate: :accordingTo (<http://www.example.org/accordingTo>) with node id 4 to plantuml
# Converting node Reifies with node id 6 to plantuml
# Converting node NonAssertedTriple with node id 9 to plantuml
# Converting node Iri: :employee22 (http://www.example.org/employee22) with node id 5 to plantuml
# Converting node Literal: "Assistant Designer" with node id 8 to plantuml
# Converting node Predicate: :jobTitle (<http://www.example.org/jobTitle>) with node id 7 to plantuml
# [{'filename': 'out.puml', 'gen_success': True}]

# %% [markdown]
# ### Annotation syntax

# %%
# Clean the workspace
# !rm -f out.puml out.pnf
rudof.reset_all()

# %% [markdown]
# It is also possible to use the annotation syntax where a statement can be annotated with `{|` and `|}` as follows:

# %%
rudof.read_data_str("""
 PREFIX : <http://example.com/>
 PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
 :alice :name "Alice" ~ :t {|
   :statedBy :bob ;
   :recorded "2021-07-07"^^xsd:date
 |} .
 """)

# %%
uml = rudof.data2plantuml_file('out.puml')
# !python -m plantuml out.puml
Image(f"out.png")
# Out:
# Visual graph: VisualRDFGraph with 10 nodes and 4 edges
# Node 6: Predicate: :recorded (<http://example.com/recorded>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 2: Literal: "Alice"
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 1 }
# Node 4: Reifies
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 5: AssertedTriple
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 7: Literal: "2021-07-07"^^xsd:date
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 3: Iri: :t (http://example.com/t)
#      count: UsageCount { as_predicate: 0, as_subject: 3, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 1: Predicate: :name (<http://example.com/name>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 1, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 8: Predicate: :statedBy (<http://example.com/statedBy>)
#      count: UsageCount { as_predicate: 1, as_subject: 0, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Node 0: Iri: :alice (http://example.com/alice)
#      count: UsageCount { as_predicate: 0, as_subject: 1, as_object: 0, as_predicate_in_triple: 0, as_subject_in_triple: 1, as_object_in_triple: 0 }
# Node 9: Iri: :bob (http://example.com/bob)
#      count: UsageCount { as_predicate: 0, as_subject: 0, as_object: 1, as_predicate_in_triple: 0, as_subject_in_triple: 0, as_object_in_triple: 0 }
# Edge reifies: 3 --> 5
# Edge :recorded (http://example.com/recorded): 3 --> 7
# Edge :statedBy (http://example.com/statedBy): 3 --> 9
# Edge :name (http://example.com/name): 0 --> 2
# Starting conversion...
# Converting node Predicate: :recorded (<http://example.com/recorded>) with node id 6 to plantuml
# Converting node Literal: "Alice" with node id 2 to plantuml
# Converting node Reifies with node id 4 to plantuml
# Converting node AssertedTriple with node id 5 to plantuml
# Converting node Literal: "2021-07-07"^^xsd:date with node id 7 to plantuml
# Converting node Iri: :t (http://example.com/t) with node id 3 to plantuml
# Converting node Predicate: :name (<http://example.com/name>) with node id 1 to plantuml
# Converting node Predicate: :statedBy (<http://example.com/statedBy>) with node id 8 to plantuml
# Converting node Iri: :alice (http://example.com/alice) with node id 0 to plantuml
# Converting node Iri: :bob (http://example.com/bob) with node id 9 to plantuml
# [{'filename': 'out.puml', 'gen_success': True}]

# %% [markdown]
# Notice that in the visualization, we differentiate between a statement that is part of the graph which is represented by a box from a statement that is not part of the graph, which is represented by a cloud symbol.

# %% [markdown]
# ## Comparing Schemas

# %% [markdown]
# It is possible to use rudof to compare different schemas. For example:

# %%
schema1 = """
 PREFIX : <http://example.org/>
 PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
 :Person {
    :name xsd:string ;
    :age xsd:integer ;
    :weight xsd:float ;
    :worksFor .
 }
""";

# %%
schema2 = """
 PREFIX ex: <http://example.org/>
 PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
 ex:Person {
    ex:name xsd:string ;
    ex:birthDate xsd:date ;
    ex:worksFor .
}
"""

# %%
result = rudof.compare_schemas_str(
    schema1, schema2,
    "shex", "shex",
    "shexc", "shexc",
    None, None,
    "http://example.org/Person", "http://example.org/Person"
    )

# %%
print(f"Result of comparison:\n{result.as_json()}")
# Out:
# Result of comparison:
# {
#   "equal_properties": {
#     "http://example.org/worksFor": {
#       "description1": {
#         "iri_ref": "http://example.org/worksFor"
#       },
#       "description2": {
#         "iri_ref": "http://example.org/worksFor"
#       }
#     },
#     "http://example.org/name": {
#       "description1": {
#         "iri_ref": "http://example.org/name",
#         "value_constraint": {
#           "Datatype": "http://www.w3.org/2001/XMLSchema#string"
#         }
#       },
#       "description2": {
#         "iri_ref": "http://example.org/name",
#         "value_constraint": {
#           "Datatype": "http://www.w3.org/2001/XMLSchema#string"
#         }
#       }
#     }
#   },
#   "properties1": {
#     "http://example.org/weight": {
#       "description": {
#         "iri_ref": "http://example.org/weight",
#         "value_constraint": {
#           "Datatype": "http://www.w3.org/2001/XMLSchema#float"
#         }
#       }
#     },
#     "http://example.org/age": {
#       "description": {
#         "iri_ref": "http://example.org/age",
#         "value_constraint": {
#           "Datatype": "http://www.w3.org/2001/XMLSchema#integer"
#         }
#       }
#     }
#   },
#   "properties2": {
#     "http://example.org/birthDate": {
#       "description": {
#         "iri_ref": "http://example.org/birthDate",
#         "value_constraint": {
#           "Datatype": "http://www.w3.org/2001/XMLSchema#date"
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# ## Obtaining information about SPARQL endpoints

# %% [markdown]
# ### When the SPARQL endpoint directly generates the service description in RDF (Uniprot)

# %% [markdown]
# It is possible to get information from SPARQL endpoints that publish [service descriptions](https://www.w3.org/TR/sparql11-service-description/) using the [VoID](https://www.w3.org/TR/void/) vocabulary.

# %%
# @title

rudof.reset_all()
from pyrudof import ReaderMode, ServiceDescriptionFormat, QueryResultFormat

# %%
service = "https://sparql.uniprot.org/sparql"

rudof.read_service_description(service, RDFFormat.Turtle, None, ReaderMode.Strict)

# %% [markdown]
# Now we can serialize the service description in JSON, for example, as:

# %%
service = rudof.get_service_description()
service_str = service.serialize(ServiceDescriptionFormat.Json)
print(f"Service description in JSON:\n{service_str}")
# Out:
# Service description in JSON:
# {
#   "title": "UniProt",
#   "endpoint": "https://sparql.uniprot.org/sparql",
#   "default_dataset": {
#     "id": {
#       "Iri": "https://sparql.uniprot.org/sparql#sparql-default-dataset"
#     },
#     "default_graph": {
#       "id": {
#         "Iri": "https://sparql.uniprot.org/.well-known/void#sparql-default-graph"
#       },
#       "triples": 239686443056
#     },
#     "named_graphs": [
#       {
#         "id": {
#           "Iri": "http://sparql.uniprot.org/go"
#         },
#         "name": "http://sparql.uniprot.org/go",
#         "graphs": [
#           {
#             "id": {
#               "Iri": "http://creativecommons.org/licenses/by/4.0/"
#             }
#           },
#           {
#             "id": {
#               "Iri": "https://sparql.uniprot.org/.well-known/void#_graph_go!6a4e0939"
#             },
#             "triples": 694229,
#             "classes": 3,
#             "property_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!2aadd92f!replaces"
#                 },
#                 "property": "http://www.geneontology.org/formats/oboInOwl#replaces",
#                 "triples": 3646
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!b6c99360!subClassOf"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#subClassOf",
#                 "triples": 412653
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!f48ccabe!imports"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#imports",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!ebe63073!someValuesFrom"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#someValuesFrom",
#                 "triples": 7819
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!15e3ca39!IAO_0000115"
#                 },
#                 "property": "http://purl.obolibrary.org/obo/IAO_0000115",
#                 "triples": 48022
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!07fd2e02!onProperty"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#onProperty",
#                 "triples": 7819
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!4f75ce12!label"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#label",
#                 "triples": 48022
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!5052af0b!hasRelatedSynonym"
#                 },
#                 "property": "http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym",
#                 "triples": 44233
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!c74e2b73!type"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
#                 "triples": 59488
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!079d1ff4!hasExactSynonym"
#                 },
#                 "property": "http://www.geneontology.org/formats/oboInOwl#hasExactSynonym",
#                 "triples": 62526
#               }
#             ],
#             "class_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!6be100d0!Class"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Class"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!9ed2fb7d!Restriction"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Restriction"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#go!89df24df!Ontology"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Ontology"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": {
#           "Iri": "http://purl.uniprot.org/core"
#         },
#         "name": "http://purl.uniprot.org/core",
#         "graphs": [
#           {
#             "id": {
#               "Iri": "http://creativecommons.org/licenses/by/4.0/"
#             }
#           },
#           {
#             "id": {
#               "Iri": "https://sparql.uniprot.org/.well-known/void#_graph_core!0daedae9"
#             },
#             "triples": 2816,
#             "classes": 19,
#             "property_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!5a36ccee!hasValue"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#hasValue",
#                 "triples": 3
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!feda1d30!description"
#                 },
#                 "property": "http://purl.org/dc/terms/description",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!3494e2ce!license"
#                 },
#                 "property": "http://purl.org/dc/terms/license",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!b6c99360!subClassOf"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#subClassOf",
#                 "triples": 168
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!2285a2da!versionInfo"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#versionInfo",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!50a1cf2d!allValuesFrom"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#allValuesFrom",
#                 "triples": 12
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!cdc148f9!isDefinedBy"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#isDefinedBy",
#                 "triples": 362
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!26363953!onClass"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#onClass",
#                 "triples": 13
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!d89567f0!domain"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#domain",
#                 "triples": 131
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!8bee1528!status"
#                 },
#                 "property": "http://purl.org/ontology/bibo/status",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!4c92f034!distinctMembers"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#distinctMembers",
#                 "triples": 14
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!5bba4b7c!intersectionOf"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#intersectionOf",
#                 "triples": 6
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!7e72e214!seeAlso"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#seeAlso",
#                 "triples": 116
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!6d4c6c11!unionOf"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#unionOf",
#                 "triples": 32
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!f48ccabe!imports"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#imports",
#                 "triples": 5
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!dacf627f!comment"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#comment",
#                 "triples": 224
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!45a800b1!inverseOf"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#inverseOf",
#                 "triples": 4
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!6a744d33!rest"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#rest",
#                 "triples": 193
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!b353b4ca!deprecated"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#deprecated",
#                 "triples": 59
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!bbfcc21a!equivalentClass"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#equivalentClass",
#                 "triples": 19
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!1c05cf51!maxQualifiedCardinality"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#maxQualifiedCardinality",
#                 "triples": 8
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!bb4d41ac!example"
#                 },
#                 "property": "http://purl.org/vocab/vann/example",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!8cbd77d5!abstract"
#                 },
#                 "property": "http://purl.org/dc/terms/abstract",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!af693ddc!introduction"
#                 },
#                 "property": "https://w3id.org/widoco/vocab#introduction",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!0b7059f5!qualifiedCardinality"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#qualifiedCardinality",
#                 "triples": 5
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!ebe63073!someValuesFrom"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#someValuesFrom",
#                 "triples": 6
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!07fd2e02!onProperty"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#onProperty",
#                 "triples": 45
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!3f2ae919!title"
#                 },
#                 "property": "http://purl.org/dc/terms/title",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!863e2c9c!disjointWith"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#disjointWith",
#                 "triples": 7
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!f1f283de!maxCardinality"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#maxCardinality",
#                 "triples": 2
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!b60d90ef!subPropertyOf"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#subPropertyOf",
#                 "triples": 22
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!4f75ce12!label"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#label",
#                 "triples": 364
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!bda135ba!minCardinality"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#minCardinality",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!1460f536!preferredNamespacePrefix"
#                 },
#                 "property": "http://purl.org/vocab/vann/preferredNamespacePrefix",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!3536baaa!first"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#first",
#                 "triples": 193
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!578d0880!range"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#range",
#                 "triples": 116
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!c8424c21!oneOf"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#oneOf",
#                 "triples": 3
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!aad154f0!cardinality"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#cardinality",
#                 "triples": 8
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!c74e2b73!type"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
#                 "triples": 666
#               }
#             ],
#             "class_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!89df24df!Ontology"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Ontology"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!e70106cf!Datatype"
#                 },
#                 "class": "http://www.w3.org/2000/01/rdf-schema#Datatype"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!9e2e8496!Organelle"
#                 },
#                 "class": "http://purl.uniprot.org/core/Organelle"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!472ee8b9!ObjectProperty"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#ObjectProperty"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!c012b7ec!InverseFunctionalProperty"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#InverseFunctionalProperty"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!6493ba7c!Rank"
#                 },
#                 "class": "http://purl.uniprot.org/core/Rank"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!9ed2fb7d!Restriction"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Restriction"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!e3f70d87!Structure_Determination_Method"
#                 },
#                 "class": "http://purl.uniprot.org/core/Structure_Determination_Method"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!717e1ac2!FunctionalProperty"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#FunctionalProperty"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!17624ea2!Protein_Existence"
#                 },
#                 "class": "http://purl.uniprot.org/core/Protein_Existence"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!44424c25!Mass_Measurement_Method"
#                 },
#                 "class": "http://purl.uniprot.org/core/Mass_Measurement_Method"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!9e6d9edd!DatatypeProperty"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#DatatypeProperty"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!0b6c09b2!Status"
#                 },
#                 "class": "http://purl.uniprot.org/core/Status"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!17b4b079!AllDifferent"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#AllDifferent"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!5d8d7b26!Thing"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Thing"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!55439a5d!AnnotationProperty"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#AnnotationProperty"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!137c9dc1!List"
#                 },
#                 "class": "http://www.w3.org/1999/02/22-rdf-syntax-ns#List"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!6be100d0!Class"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Class"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#core!bb70ba4a!NamedIndividual"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#NamedIndividual"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": {
#           "Iri": "http://sparql.uniprot.org/tissues"
#         },
#         "name": "http://sparql.uniprot.org/tissues",
#         "graphs": [
#           {
#             "id": {
#               "Iri": "https://sparql.uniprot.org/.well-known/void#_graph_tissues!52a68905"
#             },
#             "triples": 4113,
#             "classes": 2,
#             "property_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!c74e2b73!type"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
#                 "triples": 1333
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!8d3b7b43!prefLabel"
#                 },
#                 "property": "http://www.w3.org/2004/02/skos/core#prefLabel",
#                 "triples": 1332
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!efdd8743!database"
#                 },
#                 "property": "http://purl.uniprot.org/core/database",
#                 "triples": 93
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!7e72e214!seeAlso"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#seeAlso",
#                 "triples": 113
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!f48ccabe!imports"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#imports",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!07d92ae6!altLabel"
#                 },
#                 "property": "http://www.w3.org/2004/02/skos/core#altLabel",
#                 "triples": 1147
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!dacf627f!comment"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#comment",
#                 "triples": 94
#               }
#             ],
#             "class_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!89df24df!Ontology"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Ontology"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#tissues!5787c183!Tissue"
#                 },
#                 "class": "http://purl.uniprot.org/core/Tissue"
#               }
#             ]
#           },
#           {
#             "id": {
#               "Iri": "http://creativecommons.org/licenses/by/4.0/"
#             }
#           }
#         ]
#       },
#       {
#         "id": {
#           "Iri": "https://sparql.rhea-db.org/rhea"
#         },
#         "name": "https://sparql.rhea-db.org/rhea",
#         "graphs": [
#           {
#             "id": {
#               "Iri": "http://creativecommons.org/licenses/by/4.0/"
#             }
#           },
#           {
#             "id": {
#               "Iri": "https://sparql.uniprot.org/.well-known/void#_graph_rhea!a873d337"
#             },
#             "triples": 1962186,
#             "classes": 3,
#             "property_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!aa48b3b7!isTransport"
#                 },
#                 "property": "http://rdf.rhea-db.org/isTransport",
#                 "triples": 71132
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!1861ce30!contains"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains",
#                 "triples": 86441
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!6332ac57!equation"
#                 },
#                 "property": "http://rdf.rhea-db.org/equation",
#                 "triples": 71132
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!3f0f3ac3!contains11"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains11",
#                 "triples": 15
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!cde5b30b!ec"
#                 },
#                 "property": "http://rdf.rhea-db.org/ec",
#                 "triples": 7858
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!da0243cd!contains18"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains18",
#                 "triples": 4
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!b8a33e45!contains7"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains7",
#                 "triples": 44
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!a6a462f3!contains27"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains27",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!251aebdd!contains28"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains28",
#                 "triples": 3
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!7e72e214!seeAlso"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#seeAlso",
#                 "triples": 24482
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!903739d8!containsNminus1"
#                 },
#                 "property": "http://rdf.rhea-db.org/containsNminus1",
#                 "triples": 4
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!1850a0d1!contains19"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains19",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!f220e743!contains13"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains13",
#                 "triples": 4
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!05e701d0!citation"
#                 },
#                 "property": "http://rdf.rhea-db.org/citation",
#                 "triples": 148992
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!d4c4c508!contains16"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains16",
#                 "triples": 15
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!bb456c70!coefficient"
#                 },
#                 "property": "http://rdf.rhea-db.org/coefficient",
#                 "triples": 31
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!04a55745!compound"
#                 },
#                 "property": "http://rdf.rhea-db.org/compound",
#                 "triples": 86433
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!360abd9c!contains20"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains20",
#                 "triples": 3
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!c071fa1e!charge"
#                 },
#                 "property": "http://rdf.rhea-db.org/charge",
#                 "triples": 14744
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!dacf627f!comment"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#comment",
#                 "triples": 11764
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!13aee3df!htmlEquation"
#                 },
#                 "property": "http://rdf.rhea-db.org/htmlEquation",
#                 "triples": 71132
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!aaa6bd42!curatedOrder"
#                 },
#                 "property": "http://rdf.rhea-db.org/curatedOrder",
#                 "triples": 35566
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!15390109!contains10"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains10",
#                 "triples": 18
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!eb3db1b3!substrates"
#                 },
#                 "property": "http://rdf.rhea-db.org/substrates",
#                 "triples": 35566
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!b587ff11!substratesOrProducts"
#                 },
#                 "property": "http://rdf.rhea-db.org/substratesOrProducts",
#                 "triples": 35566
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!178cd26b!location"
#                 },
#                 "property": "http://rdf.rhea-db.org/location",
#                 "triples": 5111
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!6e81f6ec!side"
#                 },
#                 "property": "http://rdf.rhea-db.org/side",
#                 "triples": 35566
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!a8aa015c!containsNplus1"
#                 },
#                 "property": "http://rdf.rhea-db.org/containsNplus1",
#                 "triples": 5
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!7a0bc350!contains9"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains9",
#                 "triples": 26
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!6f836d1e!directionalReaction"
#                 },
#                 "property": "http://rdf.rhea-db.org/directionalReaction",
#                 "triples": 36142
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!25568ad2!isChemicallyBalanced"
#                 },
#                 "property": "http://rdf.rhea-db.org/isChemicallyBalanced",
#                 "triples": 71132
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!0d802c92!formula"
#                 },
#                 "property": "http://rdf.rhea-db.org/formula",
#                 "triples": 14744
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!013a48fe!underlyingChebi"
#                 },
#                 "property": "http://rdf.rhea-db.org/underlyingChebi",
#                 "triples": 261
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!e39dce5d!contains17"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains17",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!f1ed84ac!contains5"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains5",
#                 "triples": 118
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!678dd81b!chebi"
#                 },
#                 "property": "http://rdf.rhea-db.org/chebi",
#                 "triples": 14485
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!3d5d1900!id"
#                 },
#                 "property": "http://rdf.rhea-db.org/id",
#                 "triples": 86938
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!2b4b0d54!contains40"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains40",
#                 "triples": 4
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!d85abfe9!contains21"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains21",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!b60d90ef!subPropertyOf"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#subPropertyOf",
#                 "triples": 31
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!91527023!status"
#                 },
#                 "property": "http://rdf.rhea-db.org/status",
#                 "triples": 72284
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!4dc83ac6!contains8"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains8",
#                 "triples": 108
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!adab45cf!contains24"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains24",
#                 "triples": 2
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!c74e2b73!type"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
#                 "triples": 223468
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!819e57ec!contains6"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains6",
#                 "triples": 135
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!0182cdd9!contains1"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains1",
#                 "triples": 79818
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!64a5cf69!contains26"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains26",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!6960e481!contains3"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains3",
#                 "triples": 797
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!335b2de6!contains2"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains2",
#                 "triples": 4674
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!658b899a!contains14"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains14",
#                 "triples": 2
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!df31458f!polymerizationIndex"
#                 },
#                 "property": "http://rdf.rhea-db.org/polymerizationIndex",
#                 "triples": 261
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!b8f23b56!containsN"
#                 },
#                 "property": "http://rdf.rhea-db.org/containsN",
#                 "triples": 176
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!dbb3ba06!accession"
#                 },
#                 "property": "http://rdf.rhea-db.org/accession",
#                 "triples": 86938
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!4f75ce12!label"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#label",
#                 "triples": 71148
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!0a78e122!name"
#                 },
#                 "property": "http://rdf.rhea-db.org/name",
#                 "triples": 16643
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!77b20cb4!position"
#                 },
#                 "property": "http://rdf.rhea-db.org/position",
#                 "triples": 459
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!d5a6117d!products"
#                 },
#                 "property": "http://rdf.rhea-db.org/products",
#                 "triples": 35566
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!e59633c5!contains2n"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains2n",
#                 "triples": 11
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!b5776368!transformableTo"
#                 },
#                 "property": "http://rdf.rhea-db.org/transformableTo",
#                 "triples": 35566
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!d8396ad9!contains12"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains12",
#                 "triples": 18
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!20379203!reactivePart"
#                 },
#                 "property": "http://rdf.rhea-db.org/reactivePart",
#                 "triples": 1989
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!b6c99360!subClassOf"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#subClassOf",
#                 "triples": 331460
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!19e68803!contains22"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains22",
#                 "triples": 3
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!84ccb1cf!contains32"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains32",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!79bfe689!htmlName"
#                 },
#                 "property": "http://rdf.rhea-db.org/htmlName",
#                 "triples": 16643
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!0542e93e!contains4"
#                 },
#                 "property": "http://rdf.rhea-db.org/contains4",
#                 "triples": 428
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!0869bd0d!bidirectionalReaction"
#                 },
#                 "property": "http://rdf.rhea-db.org/bidirectionalReaction",
#                 "triples": 18071
#               }
#             ],
#             "class_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!ad808933!Class"
#                 },
#                 "class": "http://www.w3.org/2000/01/rdf-schema#Class"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!80029ef2!Property"
#                 },
#                 "class": "http://www.w3.org/1999/02/22-rdf-syntax-ns#Property"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!6be100d0!Class"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Class"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": {
#           "Iri": "http://sparql.uniprot.org/uniref"
#         },
#         "name": "http://sparql.uniprot.org/uniref",
#         "graphs": [
#           {
#             "id": {
#               "Iri": "https://sparql.uniprot.org/.well-known/void#_graph_uniref!be782655"
#             },
#             "triples": 10725598838,
#             "classes": 3,
#             "property_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!35f69f16!seedFor"
#                 },
#                 "property": "http://purl.uniprot.org/core/seedFor",
#                 "triples": 743534908
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!133b6ed7!member"
#                 },
#                 "property": "http://purl.uniprot.org/core/member",
#                 "triples": 1486288395
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!470195ec!organism"
#                 },
#                 "property": "http://purl.uniprot.org/core/organism",
#                 "triples": 264943047
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!d1a3894a!identity"
#                 },
#                 "property": "http://purl.uniprot.org/core/identity",
#                 "triples": 743534908
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!c6576eb7!modified"
#                 },
#                 "property": "http://purl.uniprot.org/core/modified",
#                 "triples": 743534908
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!584cbb6f!sequenceFor"
#                 },
#                 "property": "http://purl.uniprot.org/core/sequenceFor",
#                 "triples": 253676601
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!799b3e2e!memberOf"
#                 },
#                 "property": "http://purl.uniprot.org/core/memberOf",
#                 "triples": 1456158490
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!e2bc0a98!someMembersClassifiedWith"
#                 },
#                 "property": "http://purl.uniprot.org/core/someMembersClassifiedWith",
#                 "triples": 321749097
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!f48ccabe!imports"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#imports",
#                 "triples": 1
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!a23a2497!representativeFor"
#                 },
#                 "property": "http://purl.uniprot.org/core/representativeFor",
#                 "triples": 743534908
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!4f75ce12!label"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#label",
#                 "triples": 1492668395
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!c74e2b73!type"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
#                 "triples": 1238976754
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!4838475e!commonTaxon"
#                 },
#                 "property": "http://purl.uniprot.org/core/commonTaxon",
#                 "triples": 741556573
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!e2736da7!length"
#                 },
#                 "property": "http://purl.uniprot.org/core/length",
#                 "triples": 495441853
#               }
#             ],
#             "class_partition": [
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!89df24df!Ontology"
#                 },
#                 "class": "http://www.w3.org/2002/07/owl#Ontology"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!9dfa0ced!Cluster"
#                 },
#                 "class": "http://purl.uniprot.org/core/Cluster"
#               },
#               {
#                 "id": {
#                   "Iri": "https://sparql.uniprot.org/.well-known/void#uniref!5999abf9!Sequence"
#                 },
# ...
#                   },
#                   "property": "http://rdf.rhea-db.org/contains12",
#                   "triples": 18
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!f1ed84ac!contains5"
#                   },
#                   "property": "http://rdf.rhea-db.org/contains5",
#                   "triples": 118
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!678dd81b!chebi"
#                   },
#                   "property": "http://rdf.rhea-db.org/chebi",
#                   "triples": 14485
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!c071fa1e!charge"
#                   },
#                   "property": "http://rdf.rhea-db.org/charge",
#                   "triples": 14744
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!b587ff11!substratesOrProducts"
#                   },
#                   "property": "http://rdf.rhea-db.org/substratesOrProducts",
#                   "triples": 35566
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!dacf627f!comment"
#                   },
#                   "property": "http://www.w3.org/2000/01/rdf-schema#comment",
#                   "triples": 11764
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!84ccb1cf!contains32"
#                   },
#                   "property": "http://rdf.rhea-db.org/contains32",
#                   "triples": 1
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!aa48b3b7!isTransport"
#                   },
#                   "property": "http://rdf.rhea-db.org/isTransport",
#                   "triples": 71132
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!819e57ec!contains6"
#                   },
#                   "property": "http://rdf.rhea-db.org/contains6",
#                   "triples": 135
#                 }
#               ],
#               "class_partition": [
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!6be100d0!Class"
#                   },
#                   "class": "http://www.w3.org/2002/07/owl#Class"
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!ad808933!Class"
#                   },
#                   "class": "http://www.w3.org/2000/01/rdf-schema#Class"
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#rhea!80029ef2!Property"
#                   },
#                   "class": "http://www.w3.org/1999/02/22-rdf-syntax-ns#Property"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "id": {
#             "Iri": "http://sparql.uniprot.org/diseases"
#           },
#           "name": "http://sparql.uniprot.org/diseases",
#           "graphs": [
#             {
#               "id": {
#                 "Iri": "http://creativecommons.org/licenses/by/4.0/"
#               }
#             },
#             {
#               "id": {
#                 "Iri": "https://sparql.uniprot.org/.well-known/void#_graph_diseases!066a5bb5"
#               },
#               "triples": 89127,
#               "classes": 2,
#               "property_partition": [
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!efdd8743!database"
#                   },
#                   "property": "http://purl.uniprot.org/core/database",
#                   "triples": 16146
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!dacf627f!comment"
#                   },
#                   "property": "http://www.w3.org/2000/01/rdf-schema#comment",
#                   "triples": 13483
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!7ba5f664!mnemonic"
#                   },
#                   "property": "http://purl.uniprot.org/core/mnemonic",
#                   "triples": 6816
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!7e72e214!seeAlso"
#                   },
#                   "property": "http://www.w3.org/2000/01/rdf-schema#seeAlso",
#                   "triples": 28287
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!07d92ae6!altLabel"
#                   },
#                   "property": "http://www.w3.org/2004/02/skos/core#altLabel",
#                   "triples": 10761
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!c74e2b73!type"
#                   },
#                   "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
#                   "triples": 6817
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!f48ccabe!imports"
#                   },
#                   "property": "http://www.w3.org/2002/07/owl#imports",
#                   "triples": 1
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!8d3b7b43!prefLabel"
#                   },
#                   "property": "http://www.w3.org/2004/02/skos/core#prefLabel",
#                   "triples": 6816
#                 }
#               ],
#               "class_partition": [
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!89df24df!Ontology"
#                   },
#                   "class": "http://www.w3.org/2002/07/owl#Ontology"
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#diseases!962fa7e0!Disease"
#                   },
#                   "class": "http://purl.uniprot.org/core/Disease"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "id": {
#             "Iri": "http://sparql.uniprot.org/go"
#           },
#           "name": "http://sparql.uniprot.org/go",
#           "graphs": [
#             {
#               "id": {
#                 "Iri": "http://creativecommons.org/licenses/by/4.0/"
#               }
#             },
#             {
#               "id": {
#                 "Iri": "https://sparql.uniprot.org/.well-known/void#_graph_go!6a4e0939"
#               },
#               "triples": 694229,
#               "classes": 3,
#               "property_partition": [
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!c74e2b73!type"
#                   },
#                   "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
#                   "triples": 59488
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!5052af0b!hasRelatedSynonym"
#                   },
#                   "property": "http://www.geneontology.org/formats/oboInOwl#hasRelatedSynonym",
#                   "triples": 44233
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!079d1ff4!hasExactSynonym"
#                   },
#                   "property": "http://www.geneontology.org/formats/oboInOwl#hasExactSynonym",
#                   "triples": 62526
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!4f75ce12!label"
#                   },
#                   "property": "http://www.w3.org/2000/01/rdf-schema#label",
#                   "triples": 48022
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!07fd2e02!onProperty"
#                   },
#                   "property": "http://www.w3.org/2002/07/owl#onProperty",
#                   "triples": 7819
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!b6c99360!subClassOf"
#                   },
#                   "property": "http://www.w3.org/2000/01/rdf-schema#subClassOf",
#                   "triples": 412653
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!15e3ca39!IAO_0000115"
#                   },
#                   "property": "http://purl.obolibrary.org/obo/IAO_0000115",
#                   "triples": 48022
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!ebe63073!someValuesFrom"
#                   },
#                   "property": "http://www.w3.org/2002/07/owl#someValuesFrom",
#                   "triples": 7819
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!2aadd92f!replaces"
#                   },
#                   "property": "http://www.geneontology.org/formats/oboInOwl#replaces",
#                   "triples": 3646
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!f48ccabe!imports"
#                   },
#                   "property": "http://www.w3.org/2002/07/owl#imports",
#                   "triples": 1
#                 }
#               ],
#               "class_partition": [
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!9ed2fb7d!Restriction"
#                   },
#                   "class": "http://www.w3.org/2002/07/owl#Restriction"
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!89df24df!Ontology"
#                   },
#                   "class": "http://www.w3.org/2002/07/owl#Ontology"
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#go!6be100d0!Class"
#                   },
#                   "class": "http://www.w3.org/2002/07/owl#Class"
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "id": {
#             "Iri": "http://sparql.uniprot.org/obsolete"
#           },
#           "name": "http://sparql.uniprot.org/obsolete",
#           "graphs": [
#             {
#               "id": {
#                 "Iri": "http://creativecommons.org/licenses/by/4.0/"
#               }
#             },
#             {
#               "id": {
#                 "Iri": "https://sparql.uniprot.org/.well-known/void#_graph_obsolete!d9b2c794"
#               },
#               "triples": 1504004769,
#               "classes": 3,
#               "property_partition": [
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!44b39d8b!created"
#                   },
#                   "property": "http://purl.uniprot.org/core/created",
#                   "triples": 192232720
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!65ea9ead!replacedBy"
#                   },
#                   "property": "http://purl.uniprot.org/core/replacedBy",
#                   "triples": 8168978
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!b7389555!withdrawnFromINSDC"
#                   },
#                   "property": "http://purl.uniprot.org/core/withdrawnFromINSDC",
#                   "triples": 113
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!7ba5f664!mnemonic"
#                   },
#                   "property": "http://purl.uniprot.org/core/mnemonic",
#                   "triples": 192129348
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!c74e2b73!type"
#                   },
#                   "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
#                   "triples": 342539081
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!34f38684!version"
#                   },
#                   "property": "http://purl.uniprot.org/core/version",
#                   "triples": 192232720
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!19b8e068!reviewed"
#                   },
#                   "property": "http://purl.uniprot.org/core/reviewed",
#                   "triples": 192234544
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!c6576eb7!modified"
#                   },
#                   "property": "http://purl.uniprot.org/core/modified",
#                   "triples": 192232720
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!da3e1a51!obsolete"
#                   },
#                   "property": "http://purl.uniprot.org/core/obsolete",
#                   "triples": 192234544
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!f48ccabe!imports"
#                   },
#                   "property": "http://www.w3.org/2002/07/owl#imports",
#                   "triples": 1
#                 }
#               ],
#               "class_partition": [
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!0f54bcfd!Member_Of_Redudant_Proteome"
#                   },
#                   "class": "http://purl.uniprot.org/core/Member_Of_Redudant_Proteome"
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!89df24df!Ontology"
#                   },
#                   "class": "http://www.w3.org/2002/07/owl#Ontology"
#                 },
#                 {
#                   "id": {
#                     "Iri": "https://sparql.uniprot.org/.well-known/void#obsolete!81e6dc72!Protein"
#                   },
#                   "class": "http://purl.uniprot.org/core/Protein"
#                 }
#               ]
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "prefixmap": {
#     "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
#     "pav": "http://purl.org/pav/",
#     "formats": "http://www.w3.org/ns/formats/",
#     "dcterms": "http://purl.org/dc/terms/",
#     "": "http://www.w3.org/ns/sparql-service-description#",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "void": "http://rdfs.org/ns/void#",
#     "void_ext": "http://ldf.fi/void-ext#"
#   }
# }

# %% [markdown]
# We also support the conversion from service descriptions to MIE format files:

# %%
mie = service.as_mie()
print(f"Service description in MIE format as YAML:\n{mie.as_yaml()}")
# Out:
# Service description in MIE format as YAML:
# ---
# schema_info:
#   title: UniProt
#   endpoint: "https://sparql.uniprot.org/sparql"
# prefixes:
#   pav: "http://purl.org/pav/"
#   "": "http://www.w3.org/ns/sparql-service-description#"
#   void_ext: "http://ldf.fi/void-ext#"
#   formats: "http://www.w3.org/ns/formats/"
#   dcterms: "http://purl.org/dc/terms/"
#   void: "http://rdfs.org/ns/void#"
#   rdf: "http://www.w3.org/1999/02/22-rdf-syntax-ns#"
#   xsd: "http://www.w3.org/2001/XMLSchema#"

# %% [markdown]
# ### Using SPARQL CONSTRUCT queries

# %% [markdown]
# Some endpoints, like RDFPortal, have their service description located as a named graph which can be queried using a SPARQL CONSTRUCT query. In the case of RDFPortal, the service description is located in the graph [endpoint = "https://plod.dbcls.jp/repositories/RDFPortal_VoID"
# ](endpoint = "https://plod.dbcls.jp/repositories/RDFPortal_VoID"
# ).

# %%
endpoint = "https://plod.dbcls.jp/repositories/RDFPortal_VoID"

# %%
construct_query = """
PREFIX void: <http://rdfs.org/ns/void#>
PREFIX sd: <http://www.w3.org/ns/sparql-service-description#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

CONSTRUCT WHERE {
  [
    a sd:Service ;
    sd:defaultDataset [
       a sd:Dataset ;
       sd:namedGraph [
         sd:name <http://sparql.uniprot.org/uniprot> ;
         a sd:NamedGraph ;
         sd:endpoint ?ep_url ;
         sd:graph [
           a void:Dataset ;
           void:triples ?total_count ;
           void:classes ?class_count ;
           void:properties ?property_count ;
           void:distinctObjects ?uniq_object_count ;
           void:distinctSubjects ?uniq_subject_count ;
           void:classPartition [
             void:class ?class_name ;
             void:entities ?class_triple_count
           ] ;
           void:propertyPartition [
             void:property ?property_name ;
             void:triples ?property_triple_count
           ]
         ]
       ]
     ]
  ] .
}
"""

# %% [markdown]
# It is possible to run SPARQL CONSTRUCT queries in rudof using:

# %%
rudof.add_endpoint(endpoint)

# %%
dbcls_turtle = rudof.run_query_construct_str(construct_query, QueryResultFormat.Turtle)

# %%
print(dbcls_turtle)
# Out:
# @prefix void: <http://rdfs.org/ns/void#> .
# @prefix sd: <http://www.w3.org/ns/sparql-service-description#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdf4j: <http://rdf4j.org/schema/rdf4j#> .
# @prefix sesame: <http://www.openrdf.org/schema/sesame#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix fn: <http://www.w3.org/2005/xpath-functions#> .
#
# <http://rdfportal.org/ns/svcroot> a sd:Service;
#   sd:defaultDataset <http://rdfportal.org/ns/root> .
#
# <http://rdfportal.org/ns/root> a sd:Dataset;
#   sd:namedGraph <http://rdfportal.org/ns/2c0544f688656cff12b9b69af828aaf3> .
#
# <http://rdfportal.org/ns/2c0544f688656cff12b9b69af828aaf3> a sd:NamedGraph, void:Dataset;
#   sd:name <http://sparql.uniprot.org/uniprot>;
#   sd:endpoint <https://rdfportal.org/sib/sparql>;
#   void:triples 53650641556;
#   void:classes 109;
#   void:properties 85;
#   void:distinctObjects 10294379689;
#   void:distinctSubjects 11359014123;
#   void:classPartition <http://rdfportal.org/ns/07a56ccb0233f7943db8dc74583e12cd>, <http://rdfportal.org/ns/09e287d166193b1bb334c1ee918e6734>,
#     <http://rdfportal.org/ns/0d8747a3d8e14f62a8d1bd7847e2fcb9>, <http://rdfportal.org/ns/0d8efbfb22568bc3e264ed3d915985bd>,
#     <http://rdfportal.org/ns/0f6b07db53c4dfc3736eb65e38170a5c>, <http://rdfportal.org/ns/1164fc1f249b193fdf35ca26851f2976>,
#     <http://rdfportal.org/ns/12056644897611483340bb2caf6f8c9c>, <http://rdfportal.org/ns/1274ff826cde5f398df6e8c72841e211>,
#     <http://rdfportal.org/ns/15eae2eef1f2102a49aee9ac17ce0741>, <http://rdfportal.org/ns/1e730487a45ea286639e131b581bac17>,
#     <http://rdfportal.org/ns/1f7b3a944599166b377bd1833c93c046>, <http://rdfportal.org/ns/1ffa5968db4d2538e2f294e8fe028348>,
#     <http://rdfportal.org/ns/21c55b48b516ba111107a7f98224d9b3>, <http://rdfportal.org/ns/235b4f80c427af2ad8373b1fd201a95b>,
#     <http://rdfportal.org/ns/27923baebe3698e74394f18bb2ba8835>, <http://rdfportal.org/ns/2d4edfffa9d1a07520997076cc357014>,
#     <http://rdfportal.org/ns/2d7bceb87eae338b687e018ceb0fc2e3>, <http://rdfportal.org/ns/2f8d4a9168912aebcc1e8b615454425f>,
#     <http://rdfportal.org/ns/301c9085d0b1f16dcc4efcbbcd8bbe4a>, <http://rdfportal.org/ns/3021449d18fe96d83094a155a1794c3c>,
#     <http://rdfportal.org/ns/364460df27c931987e770ec9206a3f31>, <http://rdfportal.org/ns/37254c488eda87d6dbbf001af12bb136>,
#     <http://rdfportal.org/ns/3946c1ca2deadc7cabb50c5ac897fbde>, <http://rdfportal.org/ns/3da0ea0d5d39f2cc632c7dc8cb451404>,
#     <http://rdfportal.org/ns/4193abffbb00679daaeb6af0ea8ff9bb>, <http://rdfportal.org/ns/42765e3dfc44d679373690e98bae44bb>,
#     <http://rdfportal.org/ns/42c187547e5340bce5d08a649ce5f90b>, <http://rdfportal.org/ns/4781edb33ffab1dec2478c315bdd7510>,
#     <http://rdfportal.org/ns/4fa652c4e7fa112fd7da52ade68f30c1>, <http://rdfportal.org/ns/525efedd2a4e6236c139ee851e67cf09>,
#     <http://rdfportal.org/ns/5319bea414da9e86cfe376c7bcd27eb6>, <http://rdfportal.org/ns/57b2581646ca636f0eaa6dc890cea966>,
#     <http://rdfportal.org/ns/5a293a0a51a9680133be873f188f471d>, <http://rdfportal.org/ns/5a984681ffc9a7aadf2d765d81bbb622>,
#     <http://rdfportal.org/ns/5b7c5a8e899d53716c02345839ff825c>, <http://rdfportal.org/ns/5c2c7ecf2a035e0d4bda83b90b3fc2e1>,
#     <http://rdfportal.org/ns/5c449aecd03bf20abafedd46cd5310d0>, <http://rdfportal.org/ns/5d30abc467b3592da7541fd658457f8b>,
#     <http://rdfportal.org/ns/5ed84ac81a5ad6530c2ed530ad2b9b38>, <http://rdfportal.org/ns/664e33c85a9d30a31dc0b4e36287c243>,
#     <http://rdfportal.org/ns/6b235fca679778b8c01df8e7973ef142>, <http://rdfportal.org/ns/6b43b12d10bd5d2feb39807e7fcdffff>,
#     <http://rdfportal.org/ns/6e15244cd9a66085723e113fbc342c66>, <http://rdfportal.org/ns/6ec746d5dd279fbfbd30c1ce9f7c012a>,
#     <http://rdfportal.org/ns/70c0554e7fd55f4e870cebaa10aa1463>, <http://rdfportal.org/ns/7164b05756c17545d28fe0ec374b0f66>,
#     <http://rdfportal.org/ns/720426e84c53acc699cd922a04923ebf>, <http://rdfportal.org/ns/74c1f7ca6b33ceb0e197a3e73eed36dc>,
#     <http://rdfportal.org/ns/765417b5049617b5174d03c855cfeb63>, <http://rdfportal.org/ns/778fcf5ab0eaaa4a433d37dc85f8785b>,
#     <http://rdfportal.org/ns/7f8df1dac83000ceb57f633db3d150f5>, <http://rdfportal.org/ns/81641d9a751d403e4fcac2d06d6aafaf>,
#     <http://rdfportal.org/ns/830582048b50b43603995dd1ba34bb75>, <http://rdfportal.org/ns/84bb171399ae5634ef516e55c871dc3d>,
#     <http://rdfportal.org/ns/91a3f42d0c558121046b72dde99fa7d4>, <http://rdfportal.org/ns/91dc967871d9c4844ca51f83cb7be6db>,
#     <http://rdfportal.org/ns/92cfd4f11e37a86c711fdb868fefe075>, <http://rdfportal.org/ns/9beceea72e6dc07f81ab3801c77f7ee4>,
#     <http://rdfportal.org/ns/a220fa341d3ec629c6eac53fa5eff359>, <http://rdfportal.org/ns/a6219df16a8b6363231acf5b2d86b7f4>,
#     <http://rdfportal.org/ns/a6b136b63ec0f96d5c4c1b93a4e8ae29>, <http://rdfportal.org/ns/a78e2d3050c39459f1c46f142db32aaf>,
#     <http://rdfportal.org/ns/a96ffd968b8948cec240a4df3c9021a3>, <http://rdfportal.org/ns/a9842f33ba1b20291f832c85e0b60e4d>,
#     <http://rdfportal.org/ns/adc311169826ac9b05c8d3a7d182df51>, <http://rdfportal.org/ns/afad339ecc918819b698bf7eebf593c5>,
#     <http://rdfportal.org/ns/b07af80049c3c19618ae9216b3ae4719>, <http://rdfportal.org/ns/b1b2dd0f458a93bd96769bb645d85b15>,
#     <http://rdfportal.org/ns/b1be2c885b12d1d451dea22a08caa9de>, <http://rdfportal.org/ns/b4ba4cb41b70a07ec04b0af7db79d508>,
#     <http://rdfportal.org/ns/b6681d40b12e3ca4017252a5f704193a>, <http://rdfportal.org/ns/b87320c87c6a0b5ab6ad9af0f1538042>,
#     <http://rdfportal.org/ns/ba956b5151fe41467144242571241533>, <http://rdfportal.org/ns/baf433a60317a922894c49dd57e85178>,
#     <http://rdfportal.org/ns/bbd56de9aed5d3d260c9df759fd352b4>, <http://rdfportal.org/ns/bc3f2ee5002ffbffa170f40c2508914a>,
#     <http://rdfportal.org/ns/be04539c845200b6daee3b1ec6004420>, <http://rdfportal.org/ns/c503969ca88a1e4ead279c8a1f6f095e>,
#     <http://rdfportal.org/ns/c585913fda0da7397ed9e0ae838b5aef>, <http://rdfportal.org/ns/c5a2e27eaecd0e20dda7f3c0f4049712>,
#     <http://rdfportal.org/ns/c6dc1553317afe855fc205d6ae4ceeb3>, <http://rdfportal.org/ns/cbbb10874ac0db9cca62be3cfbfa4770>,
#     <http://rdfportal.org/ns/d011e2e479d98a040eff9671f22e98fc>, <http://rdfportal.org/ns/dac16526e2f104c06cc7966dfbb450a9>,
#     <http://rdfportal.org/ns/db32ea08cba8edd3c3c3b871423edc44>, <http://rdfportal.org/ns/dc5977b71a8df0e958d6552b651d35b7>,
#     <http://rdfportal.org/ns/dd83198f305a3359b0119351a3a480f1>, <http://rdfportal.org/ns/ddfac0291c8dd73b330cf2044c2ec8c4>,
#     <http://rdfportal.org/ns/e1d6dae915684ca92380ae7e1ff8f68d>, <http://rdfportal.org/ns/e23065c09fa93631dbaa90b9eb7ef552>,
#     <http://rdfportal.org/ns/e301855029e71a0f26d4bd2c74b62169>, <http://rdfportal.org/ns/e4388631b6677b64f13ad3911fb413b3>,
#     <http://rdfportal.org/ns/e5115f22a21fab8c9cd02c59795cf812>, <http://rdfportal.org/ns/e5142fb21a1fc831fce9423201a60e85>,
#     <http://rdfportal.org/ns/e6a5c1505d851d092a2b98bfbb478b1f>, <http://rdfportal.org/ns/e73a7f8415984899bda09dc9b9ff0fbd>,
#     <http://rdfportal.org/ns/e92b4496513eca1edbbfbf84d5621a71>, <http://rdfportal.org/ns/e973c376c96895910750a220b0bef373>,
#     <http://rdfportal.org/ns/eb74200e1b8a382112584b18368c88a4>, <http://rdfportal.org/ns/ed291b1db56716194ce40d0636b3a0e0>,
#     <http://rdfportal.org/ns/eec3bf688a52011540a5c1b9482bcece>, <http://rdfportal.org/ns/ef012a1166375bd7721ed56d7edb370e>,
#     <http://rdfportal.org/ns/efb479ebf2ec56f55c2e7c29cf6aca8c>, <http://rdfportal.org/ns/f2340e94b4fe1713af9f04481f07f6ea>,
#     <http://rdfportal.org/ns/f7f645337b89d7970ab12904c57c065e>, <http://rdfportal.org/ns/f84f61cc6f5d94c8abf3bfe5091d3d95>,
#     <http://rdfportal.org/ns/fa7e1b39e9359d64a44d7544f136fa1c>, <http://rdfportal.org/ns/fac5206db3a11006b533fba7b9860740>,
#     <http://rdfportal.org/ns/ff3cd39a9e77fa8ad9af1c97abedfdc0>;
#   void:propertyPartition <http://rdfportal.org/ns/068006b84e2857758882a4f53a2eab10>,
#     <http://rdfportal.org/ns/083ab4eeef0ccf988cfb283883993cb3>, <http://rdfportal.org/ns/0f2783d303c00f60fb2fd6fef47313f2>,
#     <http://rdfportal.org/ns/15088098515de2f4c96fe17ccda0d7a3>, <http://rdfportal.org/ns/170298b996a3c141f37b8391ee59c2a2>,
#     <http://rdfportal.org/ns/18a652bb46a871a9a49e68771866f00e>, <http://rdfportal.org/ns/1e4528689699198cef078e048c9b7824>,
#     <http://rdfportal.org/ns/1e7915487889f44c909ea4a363e41e96>, <http://rdfportal.org/ns/20a0c7ca80e2312223dce7e8714294fc>,
#     <http://rdfportal.org/ns/2442899b49990ee181f832da05008f24>, <http://rdfportal.org/ns/26ab55f3245fe4eb71671fe3e75fdf41>,
#     <http://rdfportal.org/ns/2bec80fbe9ac367b95365c5be3ae88ec>, <http://rdfportal.org/ns/2e050cb3f2d0b4ae04c9b8fa323bbed2>,
#     <http://rdfportal.org/ns/30c88dde57f59580f4c53229bb7b71d9>, <http://rdfportal.org/ns/342538c67f9b0425996a043680c867ba>,
#     <http://rdfportal.org/ns/34c531be01f726da56829f3d7683ecea>, <http://rdfportal.org/ns/3b30c270b37a5e5a9351f13549bb5711>,
#     <http://rdfportal.org/ns/3b4bd27369d71a1149bf923300aa2076>, <http://rdfportal.org/ns/3cadc2b5ad1513633b9a8874a29f996a>,
#     <http://rdfportal.org/ns/47554d446c30595fcadf11c2391bb149>, <http://rdfportal.org/ns/4a056f8f7893eab0f3a641d799fb8f6c>,
#     <http://rdfportal.org/ns/4ad8811262e203bb17634a1cb30d8725>, <http://rdfportal.org/ns/4b2b2b11b83a7359dbd13842e77bb63c>,
#     <http://rdfportal.org/ns/4f1a498d17bcc716fa893702e2c09123>, <http://rdfportal.org/ns/507a217b1480ff2a66100ff4bae1f9f2>,
#     <http://rdfportal.org/ns/52628fe36cbb0000db0f7532f9e8de6d>, <http://rdfportal.org/ns/52df97376a01c0ce527f09ead904dd86>,
#     <http://rdfportal.org/ns/55021d5bd2e51a0fe9a21cb56c8adc25>, <http://rdfportal.org/ns/5b8e141a3892326b5fc78bedac06abf0>,
#     <http://rdfportal.org/ns/5c3da1d6bf9c8615e9b623e96179fd7b>, <http://rdfportal.org/ns/5fa9757cc6e5c0b69b71935c1fb1915f>,
#     <http://rdfportal.org/ns/618f8acb14dc02b45642b064ce7d02de>, <http://rdfportal.org/ns/61e63b36d6c6cf1e4fec8b6756cc2d9c>,
#     <http://rdfportal.org/ns/62576f2e248bfc495ae75cdfbb5c54c7>, <http://rdfportal.org/ns/656ae83c04f0ff3fcea229b695f12246>,
#     <http://rdfportal.org/ns/6b829ca21c560f902d93bacc037d2fd9>, <http://rdfportal.org/ns/71db477b038a1b177f363f10759bcf83>,
#     <http://rdfportal.org/ns/72a5e0b694ce7b43534edddbdbb4ec62>, <http://rdfportal.org/ns/73d577524ebb991c363dcb080d187fe0>,
#     <http://rdfportal.org/ns/7925d62c90a344d160df6c45128bfdd7>, <http://rdfportal.org/ns/825b8c255fdeb2f246be06616e2d9f23>,
#     <http://rdfportal.org/ns/841bc16e30ec6725efc7ac2f42583726>, <http://rdfportal.org/ns/8456cffdaade2f214ba2ef68f8b1f6e2>,
#     <http://rdfportal.org/ns/88212c04faf1ce4dbaffe0d7406e66b4>, <http://rdfportal.org/ns/8e414f07a2e4ea9f16e2e19f031b5e75>,
#     <http://rdfportal.org/ns/8f41e3be010c80057b655f44bb710e3a>, <http://rdfportal.org/ns/933fb3873deb5948d6227ebbc76b381e>,
#     <http://rdfportal.org/ns/95eee82267f0862d03dc40808a5d0a3b>, <http://rdfportal.org/ns/9676f57279c20469836a34013b9b0d95>,
#     <http://rdfportal.org/ns/967b07323b82564925af44490c419676>, <http://rdfportal.org/ns/9caec961e050561b599cd1cbbed8940f>,
#     <http://rdfportal.org/ns/9f9640c3efd71e1282924456bea9dfd6>, <http://rdfportal.org/ns/a32878d63aab81d500155a79d70c5317>,
#     <http://rdfportal.org/ns/af3c2a749ea5f03deb7af9d21c1e030e>, <http://rdfportal.org/ns/b9f9966cc114e1c04610308685406e70>,
#     <http://rdfportal.org/ns/bc7ad2f65047b3c9703692097b99f653>, <http://rdfportal.org/ns/bcea41f57b82243eded2dfbe1812c4e9>,
#     <http://rdfportal.org/ns/bdaf9bb330fab1f8072a10cab7eb30ff>, <http://rdfportal.org/ns/bfb28b9a8ff856005188b5aa5b47d49a>,
#     <http://rdfportal.org/ns/c516d97c6236172c3fb8e6185f3ac7e4>, <http://rdfportal.org/ns/c720af7aeb9741f60850d4d1a193266b>,
#     <http://rdfportal.org/ns/c8c28693d8eb7e3eab2aee7cef9f5433>, <http://rdfportal.org/ns/cc951791e4f1e902a6af2e35963df50b>,
#     <http://rdfportal.org/ns/ce7c56b471b5b23d22208c8acf94f053>, <http://rdfportal.org/ns/d44817c74ca600eeb68ef2602449267d>,
#     <http://rdfportal.org/ns/d8c9ac45be9f00a68e8afb96c2a48204>, <http://rdfportal.org/ns/d96c532176e37f7ec1767b0d6314a425>,
#     <http://rdfportal.org/ns/dbb3f0be1a239cd85a77cce126815312>, <http://rdfportal.org/ns/df7b857ce5a78254ce9575e4635b8419>,
#     <http://rdfportal.org/ns/e08bcbb8c55f1044faa72b9630ffb2a7>, <http://rdfportal.org/ns/e171acb5096ce05b7cc6f02e36c87523>,
#     <http://rdfportal.org/ns/e1c26e06504e4ea5479432f1cd608a55>, <http://rdfportal.org/ns/e2d88cf45c27d23bba9638e9bc26a3ac>,
#     <http://rdfportal.org/ns/e41c369dbc6f14c727e106010ae4160f>, <http://rdfportal.org/ns/e49a478324d0ad7d428b67787a822431>,
#     <http://rdfportal.org/ns/ec4ea904d4bee2c74dc1dddc640c0852>, <http://rdfportal.org/ns/ee369adc3dfe2cf5deb26cab119f57bd>,
#     <http://rdfportal.org/ns/f254ba01ba90b96bbc8d6b9548449e1d>, <http://rdfportal.org/ns/f349290ab579857aa79607b64c526ec3>,
#     <http://rdfportal.org/ns/f480f83f48cf80539f21161eeb7e5d66>, <http://rdfportal.org/ns/f6449ce38048ee49928d73f74dcb06db>,
#     <http://rdfportal.org/ns/f9410d56e44a45c00ca9b5758e53b344>, <http://rdfportal.org/ns/fbadc53bd720db8ece063d46719b2288>,
#     <http://rdfportal.org/ns/fc2a825d72a59e1533e6895ecf1cf4c4>, <http://rdfportal.org/ns/ffca3c29c75c31aaac4817173d05e615>;
#   sd:graph <http://rdfportal.org/ns/2c0544f688656cff12b9b69af828aaf3> .
#
# <http://rdfportal.org/ns/07a56ccb0233f7943db8dc74583e12cd> void:class <http://purl.uniprot.org/core/Non-standard_Residue_Annotation>;
#   void:entities 21055 .
#
# <http://rdfportal.org/ns/068006b84e2857758882a4f53a2eab10> void:property <http://purl.uniprot.org/core/maximum>;
#   void:triples 133 .
#
# <http://rdfportal.org/ns/09e287d166193b1bb334c1ee918e6734> void:class <http://purl.uniprot.org/core/Non-adjacent_Residues_Annotation>;
#   void:entities 2662 .
#
# <http://rdfportal.org/ns/0d8747a3d8e14f62a8d1bd7847e2fcb9> void:class <http://purl.uniprot.org/core/Book_Citation>;
#   void:entities 785 .
#
# <http://rdfportal.org/ns/0d8efbfb22568bc3e264ed3d915985bd> void:class <http://purl.uniprot.org/core/Nucleotide_Resource>;
#   void:entities 262003968 .
#
# <http://rdfportal.org/ns/0f6b07db53c4dfc3736eb65e38170a5c> void:class <http://purl.uniprot.org/core/Gene>;
#   void:entities 233903911 .
#
# <http://rdfportal.org/ns/1164fc1f249b193fdf35ca26851f2976> void:class <http://purl.uniprot.org/core/Temperature_Dependence_Annotation>;
#   void:entities 2993 .
#
# <http://rdfportal.org/ns/12056644897611483340bb2caf6f8c9c> void:class <http://purl.uniprot.org/core/Glycosylation_Annotation>;
#   void:entities 258064 .
#
# <http://rdfportal.org/ns/1274ff826cde5f398df6e8c72841e211> void:class <http://purl.uniprot.org/core/Alternative_Promoter_Usage_Annotation>;
#   void:entities 319 .
#
# <http://rdfportal.org/ns/15eae2eef1f2102a49aee9ac17ce0741> void:class <http://purl.uniprot.org/core/Subcellular_Location_Annotation>;
#   void:entities 50935563 .
#
# <http://rdfportal.org/ns/1e730487a45ea286639e131b581bac17> void:class <http://purl.uniprot.org/core/Non-terminal_Residue_Annotation>;
#   void:entities 42873400 .
#
# <http://rdfportal.org/ns/1f7b3a944599166b377bd1833c93c046> void:class <http://biohackathon.org/resource/faldo#InRangePosition>;
#   void:entities 12141 .
#
# <http://rdfportal.org/ns/1ffa5968db4d2538e2f294e8fe028348> void:class <http://purl.uniprot.org/core/RNA_Editing_Annotation>;
#   void:entities 637 .
#
# <http://rdfportal.org/ns/21c55b48b516ba111107a7f98224d9b3> void:class <http://purl.uniprot.org/core/Caution_Annotation>;
#   void:entities 162898245 .
#
# <http://rdfportal.org/ns/235b4f80c427af2ad8373b1fd201a95b> void:class <http://purl.uniprot.org/core/Allergen_Annotation>;
#   void:entities 952 .
#
# <http://rdfportal.org/ns/27923baebe3698e74394f18bb2ba8835> void:class <http://purl.uniprot.org/core/Patent_Citation>;
#   void:entities 134 .
#
# <http://rdfportal.org/ns/2d4edfffa9d1a07520997076cc357014> void:class <http://purl.uniprot.org/core/Tissue>;
#   void:entities 24415169 .
#
# <http://rdfportal.org/ns/2d7bceb87eae338b687e018ceb0fc2e3> void:class <http://purl.uniprot.org/core/Propeptide_Annotation>;
#   void:entities 57520 .
#
# <http://rdfportal.org/ns/2f8d4a9168912aebcc1e8b615454425f> void:class <http://purl.uniprot.org/core/Beta_Strand_Annotation>;
#   void:entities 353354 .
#
# <http://rdfportal.org/ns/301c9085d0b1f16dcc4efcbbcd8bbe4a> void:class <http://purl.uniprot.org/core/Resource>;
#   void:entities 324590891 .
#
# <http://rdfportal.org/ns/3021449d18fe96d83094a155a1794c3c> void:class <http://purl.uniprot.org/core/PH_Dependence_Annotation>;
#   void:entities 5242 .
#
# <http://rdfportal.org/ns/364460df27c931987e770ec9206a3f31> void:class <http://purl.uniprot.org/core/Mass_Spectrometry_Annotation>;
#   void:entities 7575 .
#
# <http://rdfportal.org/ns/37254c488eda87d6dbbf001af12bb136> void:class <http://purl.uniprot.org/core/Induction_Annotation>;
#   void:entities 161300 .
#
# <http://rdfportal.org/ns/3946c1ca2deadc7cabb50c5ac897fbde> void:class <http://purl.uniprot.org/core/Toxic_Dose_Annotation>;
#   void:entities 869 .
#
# <http://rdfportal.org/ns/3da0ea0d5d39f2cc632c7dc8cb451404> void:class <http://purl.uniprot.org/core/Developmental_Stage_Annotation>;
#   void:entities 14510 .
#
# <http://rdfportal.org/ns/4193abffbb00679daaeb6af0ea8ff9bb> void:class <http://purl.uniprot.org/core/Plasmid>;
#   void:entities 1175927 .
#
# <http://rdfportal.org/ns/42765e3dfc44d679373690e98bae44bb> void:class <http://purl.uniprot.org/core/Structured_Name>;
#   void:entities 279501567 .
#
# <http://rdfportal.org/ns/42c187547e5340bce5d08a649ce5f90b> void:class <http://purl.uniprot.org/core/Non_Self_Interaction>;
#   void:entities 104520 .
#
# <http://rdfportal.org/ns/4781edb33ffab1dec2478c315bdd7510> void:class <http://purl.uniprot.org/core/Part>;
#   void:entities 1896952 .
#
# <http://rdfportal.org/ns/4fa652c4e7fa112fd7da52ade68f30c1> void:class <http://purl.uniprot.org/core/Thesis_Citation>;
#   void:entities 1483 .
#
# <http://rdfportal.org/ns/525efedd2a4e6236c139ee851e67cf09> void:class <http://purl.uniprot.org/core/External_Sequence>;
#   void:entities 130990 .
#
# <http://rdfportal.org/ns/5319bea414da9e86cfe376c7bcd27eb6> void:class <http://biohackathon.org/resource/faldo#OneOfPosition>;
#   void:entities 355 .
#
# <http://rdfportal.org/ns/57b2581646ca636f0eaa6dc890cea966> void:class <http://purl.uniprot.org/core/Sequence_Conflict_Annotation>;
#   void:entities 158275 .
#
# <http://rdfportal.org/ns/5a293a0a51a9680133be873f188f471d> void:class <http://purl.uniprot.org/core/Submission_Citation>;
#   void:entities 397885 .
#
# <http://rdfportal.org/ns/5a984681ffc9a7aadf2d765d81bbb622> void:class <http://purl.uniprot.org/core/Disease_Annotation>;
#   void:entities 8462 .
#
# <http://rdfportal.org/ns/5b7c5a8e899d53716c02345839ff825c> void:class <http://purl.uniprot.org/core/Chain_Annotation>;
#   void:entities 18961955 .
#
# <http://rdfportal.org/ns/5c2c7ecf2a035e0d4bda83b90b3fc2e1> void:class <http://purl.uniprot.org/core/Mutagenesis_Annotation>;
#   void:entities 99853 .
#
# <http://rdfportal.org/ns/5c449aecd03bf20abafedd46cd5310d0> void:class <http://purl.uniprot.org/core/Sequence_Uncertainty_Annotation>;
#   void:entities 120149 .
#
# <http://rdfportal.org/ns/5d30abc467b3592da7541fd658457f8b> void:class <http://purl.uniprot.org/core/PTM_Annotation>;
#   void:entities 1910995 .
#
# <http://rdfportal.org/ns/5ed84ac81a5ad6530c2ed530ad2b9b38> void:class <http://purl.uniprot.org/core/Modified_Residue_Annotation>;
#   void:entities 4549875 .
#
# <http://rdfportal.org/ns/664e33c85a9d30a31dc0b4e36287c243> void:class <http://purl.uniprot.org/core/Erroneous_Termination_Annotation>;
#   void:entities 1150 .
#
# <http://rdfportal.org/ns/6b235fca679778b8c01df8e7973ef142> void:class <http://purl.uniprot.org/core/Domain_Annotation>;
#   void:entities 2455667 .
#
# <http://rdfportal.org/ns/6b43b12d10bd5d2feb39807e7fcdffff> void:class <http://purl.uniprot.org/core/Interaction>;
#   void:entities 107648 .
#
# <http://rdfportal.org/ns/6e15244cd9a66085723e113fbc342c66> void:class <http://purl.uniprot.org/core/Erroneous_Translation_Annotation>;
#   void:entities 451 .
#
# <http://rdfportal.org/ns/6ec746d5dd279fbfbd30c1ce9f7c012a> void:class <http://purl.uniprot.org/core/Binding_Site_Annotation>;
#   void:entities 94268455 .
#
# <http://rdfportal.org/ns/70c0554e7fd55f4e870cebaa10aa1463> void:class <http://purl.uniprot.org/core/Lipidation_Annotation>;
#   void:entities 482841 .
#
# <http://rdfportal.org/ns/7164b05756c17545d28fe0ec374b0f66> void:class <http://purl.uniprot.org/core/Repeat_Annotation>;
#   void:entities 10572534 .
#
# <http://rdfportal.org/ns/720426e84c53acc699cd922a04923ebf> void:class <http://purl.uniprot.org/core/Ribosomal_Frameshifting>;
#   void:entities 769 .
#
# <http://rdfportal.org/ns/74c1f7ca6b33ceb0e197a3e73eed36dc> void:class <http://purl.uniprot.org/core/Catalytic_Activity_Annotation>;
#   void:entities 41350799 .
#
# <http://rdfportal.org/ns/765417b5049617b5174d03c855cfeb63> void:class <http://purl.uniprot.org/core/Alternative_Splicing_Annotation>;
#   void:entities 24196 .
#
# <http://rdfportal.org/ns/778fcf5ab0eaaa4a433d37dc85f8785b> void:class <http://purl.uniprot.org/core/Domain_Extent_Annotation>;
#   void:entities 192725812 .
#
# <http://rdfportal.org/ns/7f8df1dac83000ceb57f633db3d150f5> void:class <http://purl.uniprot.org/core/Disulfide_Bond_Annotation>;
#   void:entities 6282556 .
#
# <http://rdfportal.org/ns/81641d9a751d403e4fcac2d06d6aafaf> void:class <http://purl.uniprot.org/core/Region_Annotation>;
#   void:entities 99718451 .
#
# <http://rdfportal.org/ns/830582048b50b43603995dd1ba34bb75> void:class <http://purl.uniprot.org/core/Intramembrane_Annotation>;
#   void:entities 6143 .
#
# <http://rdfportal.org/ns/84bb171399ae5634ef516e55c871dc3d> void:class <http://purl.uniprot.org/core/Absorption_Annotation>;
#   void:entities 133 .
#
# <http://rdfportal.org/ns/91a3f42d0c558121046b72dde99fa7d4> void:class <http://purl.uniprot.org/core/Turn_Annotation>;
#   void:entities 83811 .
#
# <http://rdfportal.org/ns/91dc967871d9c4844ca51f83cb7be6db> void:class <http://purl.uniprot.org/core/Topological_Domain_Annotation>;
#   void:entities 610161 .
#
# <http://rdfportal.org/ns/92cfd4f11e37a86c711fdb868fefe075> void:class <http://purl.uniprot.org/core/Active_Site_Annotation>;
#   void:entities 19065823 .
#
# <http://rdfportal.org/ns/9beceea72e6dc07f81ab3801c77f7ee4> void:class <http://purl.uniprot.org/core/Subunit_Annotation>;
#   void:entities 20549250 .
#
# <http://rdfportal.org/ns/a220fa341d3ec629c6eac53fa5eff359> void:class <http://biohackathon.org/resource/faldo#Position>;
#   void:entities 1429924072 .
#
# <http://rdfportal.org/ns/a6219df16a8b6363231acf5b2d86b7f4> void:class <http://purl.uniprot.org/core/Simple_Sequence>;
#   void:entities 245896765 .
#
# <http://rdfportal.org/ns/a6b136b63ec0f96d5c4c1b93a4e8ae29> void:class <http://purl.uniprot.org/core/Citation_Statement>;
#   void:entities 287016242 .
#
# <http://rdfportal.org/ns/a78e2d3050c39459f1c46f142db32aaf> void:class rdf:Statement;
#   void:entities 3949014954 .
#
# <http://rdfportal.org/ns/a96ffd968b8948cec240a4df3c9021a3> void:class <http://purl.uniprot.org/core/Unknown_Sequence>;
#   void:entities 274 .
#
# <http://rdfportal.org/ns/a9842f33ba1b20291f832c85e0b60e4d> void:class <http://purl.uniprot.org/core/Helix_Annotation>;
#   void:entities 347050 .
#
# <http://rdfportal.org/ns/adc311169826ac9b05c8d3a7d182df51> void:class <http://purl.uniprot.org/core/Natural_Variant_Annotation>;
#   void:entities 104662 .
#
# <http://rdfportal.org/ns/afad339ecc918819b698bf7eebf593c5> void:class <http://biohackathon.org/resource/faldo#ExactPosition>;
#   void:entities 1429911576 .
#
# <http://rdfportal.org/ns/b07af80049c3c19618ae9216b3ae4719> void:class <http://purl.uniprot.org/core/Electronic_Citation>;
#   void:entities 506 .
#
# <http://rdfportal.org/ns/b1b2dd0f458a93bd96769bb645d85b15> void:class <http://purl.uniprot.org/core/Transposon>;
#   void:entities 145 .
#
# <http://rdfportal.org/ns/b1be2c885b12d1d451dea22a08caa9de> void:class <http://purl.uniprot.org/core/Tissue_Specificity_Annotation>;
#   void:entities 51398 .
#
# <http://rdfportal.org/ns/b4ba4cb41b70a07ec04b0af7db79d508> void:class <http://purl.uniprot.org/core/Modified_Sequence>;
#   void:entities 41189 .
#
# <http://rdfportal.org/ns/b6681d40b12e3ca4017252a5f704193a> void:class <http://purl.uniprot.org/core/Sequence_Caution_Annotation>;
#   void:entities 2953 .
#
# <http://rdfportal.org/ns/b87320c87c6a0b5ab6ad9af0f1538042> void:class <http://purl.uniprot.org/core/Site_Annotation>;
#   void:entities 4959059 .
#
# <http://rdfportal.org/ns/ba956b5151fe41467144242571241533> void:class <http://purl.uniprot.org/core/Redox_Potential_Annotation>;
#   void:entities 129 .
#
# <http://rdfportal.org/ns/baf433a60317a922894c49dd57e85178> void:class <http://purl.uniprot.org/core/Nucleotide_Binding_Annotation>;
#   void:entities 1907685 .
#
# <http://rdfportal.org/ns/bbd56de9aed5d3d260c9df759fd352b4> void:class <http://purl.uniprot.org/core/Kinetics_Annotation>;
#   void:entities 9419 .
#
# <http://rdfportal.org/ns/bc3f2ee5002ffbffa170f40c2508914a> void:class <http://purl.uniprot.org/core/Erroneous_Gene_Model_Prediction_Annotation>;
#   void:entities 13300 .
#
# <http://rdfportal.org/ns/be04539c845200b6daee3b1ec6004420> void:class <http://purl.uniprot.org/core/Annotation>;
#   void:entities 1263687 .
#
# <http://rdfportal.org/ns/c503969ca88a1e4ead279c8a1f6f095e> void:class <http://purl.uniprot.org/core/Transit_Peptide_Annotation>;
#   void:entities 9912 .
#
# <http://rdfportal.org/ns/c585913fda0da7397ed9e0ae838b5aef> void:class <http://purl.uniprot.org/core/Pharmaceutical_Annotation>;
#   void:entities 171 .
#
# <http://rdfportal.org/ns/c5a2e27eaecd0e20dda7f3c0f4049712> void:class <http://purl.uniprot.org/core/Motif_Annotation>;
#   void:entities 2636620 .
#
# <http://rdfportal.org/ns/c6dc1553317afe855fc205d6ae4ceeb3> void:class <http://purl.uniprot.org/core/Cross-link_Annotation>;
#   void:entities 123364 .
#
# <http://rdfportal.org/ns/cbbb10874ac0db9cca62be3cfbfa4770> void:class <http://purl.uniprot.org/core/Transmembrane_Annotation>;
#   void:entities 211543786 .
#
# <http://rdfportal.org/ns/d011e2e479d98a040eff9671f22e98fc> void:class <http://purl.uniprot.org/core/Similarity_Annotation>;
#   void:entities 90645753 .
#
# <http://rdfportal.org/ns/dac16526e2f104c06cc7966dfbb450a9> void:class <http://purl.uniprot.org/core/Coiled_Coil_Annotation>;
#   void:entities 11513540 .
#
# <http://rdfportal.org/ns/db32ea08cba8edd3c3c3b871423edc44> void:class <http://purl.uniprot.org/core/Strain>;
#   void:entities 222405855 .
#
# <http://rdfportal.org/ns/dc5977b71a8df0e958d6552b651d35b7> void:class <http://biohackathon.org/resource/faldo#Region>;
#   void:entities 823259649 .
#
# <http://rdfportal.org/ns/dd83198f305a3359b0119351a3a480f1> void:class <http://purl.uniprot.org/core/Protein>;
#   void:entities 245896765 .
#
# <http://rdfportal.org/ns/ddfac0291c8dd73b330cf2044c2ec8c4> void:class <http://purl.uniprot.org/core/Alternative_Sequence_Annotation>;
#   void:entities 53322 .
#
# <http://rdfportal.org/ns/e1d6dae915684ca92380ae7e1ff8f68d> void:class <http://purl.uniprot.org/core/Transcript_Resource>;
#   void:entities 24682063 .
#
# <http://rdfportal.org/ns/e23065c09fa93631dbaa90b9eb7ef552> void:class <http://purl.uniprot.org/core/Structure_Resource>;
#   void:entities 204789 .
#
# <http://rdfportal.org/ns/e301855029e71a0f26d4bd2c74b62169> void:class <http://purl.uniprot.org/core/Erroneous_Initiation_Annotation>;
#   void:entities 36034 .
#
# <http://rdfportal.org/ns/e4388631b6677b64f13ad3911fb413b3> void:class <http://purl.uniprot.org/core/Disruption_Phenotype_Annotation>;
#   void:entities 21431 .
#
# <http://rdfportal.org/ns/e5115f22a21fab8c9cd02c59795cf812> void:class <http://purl.uniprot.org/core/Signal_Peptide_Annotation>;
#   void:entities 17883544 .
#
# <http://rdfportal.org/ns/e5142fb21a1fc831fce9423201a60e85> void:class <http://purl.uniprot.org/core/Observation_Citation>;
#   void:entities 223 .
#
# <http://rdfportal.org/ns/e6a5c1505d851d092a2b98bfbb478b1f> void:class <http://purl.uniprot.org/core/Initiator_Methionine_Annotation>;
#   void:entities 108530 .
#
# <http://rdfportal.org/ns/e73a7f8415984899bda09dc9b9ff0fbd> void:class <http://purl.uniprot.org/core/Activity_Regulation_Annotation>;
#   void:entities 573531 .
#
# <http://rdfportal.org/ns/e92b4496513eca1edbbfbf84d5621a71> void:class <http://purl.uniprot.org/core/Pathway_Annotation>;
#   void:entities 18306067 .
#
# <http://rdfportal.org/ns/e973c376c96895910750a220b0bef373> void:class <http://purl.uniprot.org/core/Participant>;
#   void:entities 30899 .
#
# <http://rdfportal.org/ns/eb74200e1b8a382112584b18368c88a4> void:class <http://purl.uniprot.org/core/Cofactor_Annotation>;
#   void:entities 25469595 .
#
# <http://rdfportal.org/ns/ed291b1db56716194ce40d0636b3a0e0> void:class <http://purl.uniprot.org/core/Function_Annotation>;
#   void:entities 37073452 .
#
# <http://rdfportal.org/ns/eec3bf688a52011540a5c1b9482bcece> void:class <http://purl.uniprot.org/core/Peptide_Annotation>;
#   void:entities 13820 .
#
# <http://rdfportal.org/ns/ef012a1166375bd7721ed56d7edb370e> void:class <http://purl.uniprot.org/core/Compositional_Bias_Annotation>;
#   void:entities 82668021 .
#
# <http://rdfportal.org/ns/efb479ebf2ec56f55c2e7c29cf6aca8c> void:class <http://purl.uniprot.org/core/Journal_Citation>;
#   void:entities 496690 .
#
# <http://rdfportal.org/ns/f2340e94b4fe1713af9f04481f07f6ea> void:class <http://purl.uniprot.org/core/Biotechnology_Annotation>;
#   void:entities 2083 .
#
# <http://rdfportal.org/ns/f7f645337b89d7970ab12904c57c065e> void:class <http://purl.uniprot.org/core/Frameshift_Annotation>;
#   void:entities 7852 .
#
# <http://rdfportal.org/ns/f84f61cc6f5d94c8abf3bfe5091d3d95> void:class <http://purl.uniprot.org/core/Zinc_Finger_Annotation>;
#   void:entities 783639 .
#
# <http://rdfportal.org/ns/fa7e1b39e9359d64a44d7544f136fa1c> void:class <http://purl.uniprot.org/core/Polymorphism_Annotation>;
#   void:entities 1508 .
#
# <http://rdfportal.org/ns/fac5206db3a11006b533fba7b9860740> void:class <http://purl.uniprot.org/core/Alternative_Initiation_Annotation>;
#   void:entities 1080 .
#
# <http://rdfportal.org/ns/ff3cd39a9e77fa8ad9af1c97abedfdc0> void:class <http://purl.uniprot.org/core/Self_Interaction>;
#   void:entities 3128 .
#
# <http://rdfportal.org/ns/083ab4eeef0ccf988cfb283883993cb3> void:property <http://purl.uniprot.org/core/component>;
#   void:triples 833024 .
#
# <http://rdfportal.org/ns/0f2783d303c00f60fb2fd6fef47313f2> void:property <http://biohackathon.org/resource/faldo#position>;
#   void:triples 1429911576 .
#
# <http://rdfportal.org/ns/15088098515de2f4c96fe17ccda0d7a3> void:property <http://purl.uniprot.org/core/measuredError>;
#   void:triples 1231 .
#
# <http://rdfportal.org/ns/170298b996a3c141f37b8391ee59c2a2> void:property <http://purl.uniprot.org/core/experiments>;
#   void:triples 107648 .
#
# <http://rdfportal.org/ns/18a652bb46a871a9a49e68771866f00e> void:property <http://purl.uniprot.org/core/alternativeName>;
#   void:triples 30510022 .
#
# <http://rdfportal.org/ns/1e4528689699198cef078e048c9b7824> void:property <http://purl.uniprot.org/core/frameshift>;
#   void:triples 12 .
#
# <http://rdfportal.org/ns/1e7915487889f44c909ea4a363e41e96> void:property <http://www.w3.org/2004/02/skos/core#prefLabel>;
#   void:triples 57617557 .
#
# <http://rdfportal.org/ns/20a0c7ca80e2312223dce7e8714294fc> void:property <http://purl.uniprot.org/core/isolatedFrom>;
#   void:triples 18594853 .
#
# <http://rdfportal.org/ns/2442899b49990ee181f832da05008f24> void:property rdfs:seeAlso;
#   void:triples 2985734039 .
#
# <http://rdfportal.org/ns/26ab55f3245fe4eb71671fe3e75fdf41> void:property <http://biohackathon.org/resource/faldo#possiblePosition>;
#   void:triples 355 .
#
# <http://rdfportal.org/ns/2bec80fbe9ac367b95365c5be3ae88ec> void:property <http://purl.uniprot.org/core/resolution>;
#   void:triples 192899 .
#
# <http://rdfportal.org/ns/2e050cb3f2d0b4ae04c9b8fa323bbed2> void:property <http://purl.uniprot.org/core/annotation>;
#   void:triples 1279738402 .
#
# <http://rdfportal.org/ns/30c88dde57f59580f4c53229bb7b71d9> void:property rdf:value;
#   void:triples 245937954 .
#
# <http://rdfportal.org/ns/342538c67f9b0425996a043680c867ba> void:property <http://purl.uniprot.org/core/author>;
#   void:triples 4825979 .
#
# <http://rdfportal.org/ns/34c531be01f726da56829f3d7683ecea> void:property <http://purl.uniprot.org/core/context>;
#   void:triples 270752851 .
#
# <http://rdfportal.org/ns/3b30c270b37a5e5a9351f13549bb5711> void:property <http://purl.uniprot.org/core/fullName>;
#   void:triples 279499111 .
#
# <http://rdfportal.org/ns/3b4bd27369d71a1149bf923300aa2076> void:property <http://purl.uniprot.org/core/md5Checksum>;
#   void:triples 245896765 .
#
# <http://rdfportal.org/ns/3cadc2b5ad1513633b9a8874a29f996a> void:property <http://purl.uniprot.org/core/translatedFrom>;
#   void:triples 44817335 .
#
# <http://rdfportal.org/ns/47554d446c30595fcadf11c2391bb149> void:property <http://purl.uniprot.org/core/substitution>;
#   void:triples 423582 .
#
# <http://rdfportal.org/ns/4a056f8f7893eab0f3a641d799fb8f6c> void:property <http://purl.uniprot.org/core/certain>;
#   void:triples 20 .
#
# <http://rdfportal.org/ns/4ad8811262e203bb17634a1cb30d8725> void:property <http://purl.uniprot.org/core/submittedName>;
#   void:triples 138960067 .
#
# <http://rdfportal.org/ns/4b2b2b11b83a7359dbd13842e77bb63c> void:property <http://purl.uniprot.org/core/title>;
#   void:triples 792915 .
#
# <http://rdfportal.org/ns/4f1a498d17bcc716fa893702e2c09123> void:property <http://purl.uniprot.org/core/fragment>;
#   void:triples 26089848 .
#
# <http://rdfportal.org/ns/507a217b1480ff2a66100ff4bae1f9f2> void:property <http://purl.uniprot.org/core/locatedOn>;
#   void:triples 306728413 .
#
# <http://rdfportal.org/ns/52628fe36cbb0000db0f7532f9e8de6d> void:property <http://purl.uniprot.org/core/volume>;
#   void:triples 476315 .
#
# <http://rdfportal.org/ns/52df97376a01c0ce527f09ead904dd86> void:property <http://purl.org/dc/terms/identifier>;
#   void:triples 391142 .
#
# <http://rdfportal.org/ns/55021d5bd2e51a0fe9a21cb56c8adc25> void:property <http://purl.uniprot.org/core/editor>;
#   void:triples 1378 .
#
# <http://rdfportal.org/ns/5b8e141a3892326b5fc78bedac06abf0> void:property <http://purl.uniprot.org/core/pages>;
#   void:triples 470953 .
#
# <http://rdfportal.org/ns/5c3da1d6bf9c8615e9b623e96179fd7b> void:property <http://purl.uniprot.org/core/modified>;
#   void:triples 491793530 .
#
# <http://rdfportal.org/ns/5fa9757cc6e5c0b69b71935c1fb1915f> void:property <http://purl.uniprot.org/core/locusName>;
#   void:triples 5129001 .
#
# <http://rdfportal.org/ns/618f8acb14dc02b45642b064ce7d02de> void:property <http://purl.uniprot.org/core/encodedBy>;
#   void:triples 233903911 .
#
# <http://rdfportal.org/ns/61e63b36d6c6cf1e4fec8b6756cc2d9c> void:property <http://purl.uniprot.org/core/cdAntigenName>;
#   void:triples 1562 .
#
# <http://rdfportal.org/ns/62576f2e248bfc495ae75cdfbb5c54c7> void:property <http://purl.uniprot.org/core/group>;
#   void:triples 10784 .
#
# <http://rdfportal.org/ns/656ae83c04f0ff3fcea229b695f12246> void:property <http://purl.uniprot.org/core/basedOn>;
#   void:triples 41189 .
#
# <http://rdfportal.org/ns/6b829ca21c560f902d93bacc037d2fd9> void:property <http://purl.uniprot.org/core/internationalNonproprietaryName>;
#   void:triples 28 .
#
# <http://rdfportal.org/ns/71db477b038a1b177f363f10759bcf83> void:property <http://purl.uniprot.org/core/shortName>;
#   void:triples 14883222 .
#
# <http://rdfportal.org/ns/72a5e0b694ce7b43534edddbdbb4ec62> void:property <http://biohackathon.org/resource/faldo#begin>;
#   void:triples 823263568 .
#
# <http://rdfportal.org/ns/73d577524ebb991c363dcb080d187fe0> void:property <http://purl.uniprot.org/core/catalyticActivity>;
#   void:triples 41350799 .
#
# <http://rdfportal.org/ns/7925d62c90a344d160df6c45128bfdd7> void:property <http://biohackathon.org/resource/faldo#reference>;
#   void:triples 1429924072 .
#
# <http://rdfportal.org/ns/825b8c255fdeb2f246be06616e2d9f23> void:property <http://purl.uniprot.org/core/date>;
#   void:triples 897698 .
#
# <http://rdfportal.org/ns/841bc16e30ec6725efc7ac2f42583726> void:property <http://purl.uniprot.org/core/measuredAffinity>;
#   void:triples 28197 .
#
# <http://rdfportal.org/ns/8456cffdaade2f214ba2ef68f8b1f6e2> void:property <http://purl.uniprot.org/core/participant>;
#   void:triples 212168 .
#
# <http://rdfportal.org/ns/88212c04faf1ce4dbaffe0d7406e66b4> void:property <http://purl.uniprot.org/core/locator>;
#   void:triples 506 .
#
# <http://rdfportal.org/ns/8e414f07a2e4ea9f16e2e19f031b5e75> void:property rdfs:comment;
#   void:triples 973868418 .
#
# <http://rdfportal.org/ns/8f41e3be010c80057b655f44bb710e3a> void:property <http://biohackathon.org/resource/faldo#location>;
#   void:triples 2864 .
#
# <http://rdfportal.org/ns/933fb3873deb5948d6227ebbc76b381e> void:property rdf:object;
#   void:triples 3949015008 .
#
# <http://rdfportal.org/ns/95eee82267f0862d03dc40808a5d0a3b> void:property <http://purl.uniprot.org/core/scope>;
#   void:triples 287639429 .
#
# <http://rdfportal.org/ns/9676f57279c20469836a34013b9b0d95> void:property <http://purl.uniprot.org/core/translatedTo>;
#   void:triples 24697472 .
#
# <http://rdfportal.org/ns/967b07323b82564925af44490c419676> void:property <http://purl.uniprot.org/core/complete>;
#   void:triples 419059 .
#
# <http://rdfportal.org/ns/9caec961e050561b599cd1cbbed8940f> void:property <http://purl.uniprot.org/core/reviewed>;
#   void:triples 245896765 .
#
# <http://rdfportal.org/ns/9f9640c3efd71e1282924456bea9dfd6> void:property <http://purl.uniprot.org/core/version>;
#   void:triples 491793530 .
#
# <http://rdfportal.org/ns/a32878d63aab81d500155a79d70c5317> void:property <http://purl.uniprot.org/core/oldMnemonic>;
#   void:triples 204115 .
#
# <http://rdfportal.org/ns/af3c2a749ea5f03deb7af9d21c1e030e> void:property rdf:subject;
#   void:triples 3949014954 .
#
# <http://rdfportal.org/ns/b9f9966cc114e1c04610308685406e70> void:property owl:sameAs;
#   void:triples 107963 .
#
# <http://rdfportal.org/ns/bc7ad2f65047b3c9703692097b99f653> void:property <http://purl.uniprot.org/core/sequence>;
#   void:triples 246152080 .
#
# <http://rdfportal.org/ns/bcea41f57b82243eded2dfbe1812c4e9> void:property <http://purl.uniprot.org/core/created>;
#   void:triples 245896765 .
#
# <http://rdfportal.org/ns/bdaf9bb330fab1f8072a10cab7eb30ff> void:property <http://purl.uniprot.org/core/erratum>;
#   void:triples 1192 .
#
# <http://rdfportal.org/ns/bfb28b9a8ff856005188b5aa5b47d49a> void:property <http://purl.uniprot.org/core/allergenName>;
#   void:triples 866 .
#
# <http://rdfportal.org/ns/c516d97c6236172c3fb8e6185f3ac7e4> void:property <http://purl.uniprot.org/core/measuredActivity>;
#   void:triples 9324 .
#
# <http://rdfportal.org/ns/c720af7aeb9741f60850d4d1a193266b> void:property <http://purl.uniprot.org/core/precursor>;
#   void:triples 515580 .
#
# <http://rdfportal.org/ns/c8c28693d8eb7e3eab2aee7cef9f5433> void:property <http://purl.uniprot.org/core/publisher>;
#   void:triples 497 .
#
# <http://rdfportal.org/ns/cc951791e4f1e902a6af2e35963df50b> void:property <http://purl.uniprot.org/core/domain>;
#   void:triples 1063928 .
#
# <http://rdfportal.org/ns/ce7c56b471b5b23d22208c8acf94f053> void:property <http://purl.uniprot.org/core/institution>;
#   void:triples 1483 .
#
# <http://rdfportal.org/ns/d44817c74ca600eeb68ef2602449267d> void:property <http://purl.uniprot.org/core/place>;
#   void:triples 2037 .
#
# <http://rdfportal.org/ns/d8c9ac45be9f00a68e8afb96c2a48204> void:property <http://purl.uniprot.org/core/mass>;
#   void:triples 264858724 .
#
# <http://rdfportal.org/ns/d96c532176e37f7ec1767b0d6314a425> void:property <http://purl.uniprot.org/core/mnemonic>;
#   void:triples 245896765 .
#
# <http://rdfportal.org/ns/dbb3f0be1a239cd85a77cce126815312> void:property <http://purl.uniprot.org/core/name>;
#   void:triples 581698 .
#
# <http://rdfportal.org/ns/df7b857ce5a78254ce9575e4635b8419> void:property <http://purl.uniprot.org/core/modification>;
#   void:triples 62326 .
#
# <http://rdfportal.org/ns/e08bcbb8c55f1044faa72b9630ffb2a7> void:property <http://purl.uniprot.org/core/measuredValue>;
#   void:triples 7575 .
#
# <http://rdfportal.org/ns/e171acb5096ce05b7cc6f02e36c87523> void:property <http://purl.uniprot.org/core/transcribedFrom>;
#   void:triples 24662835 .
#
# <http://rdfportal.org/ns/e1c26e06504e4ea5479432f1cd608a55> void:property rdfs:label;
#   void:triples 257607494 .
#
# <http://rdfportal.org/ns/e2d88cf45c27d23bba9638e9bc26a3ac> void:property <http://biohackathon.org/resource/faldo#end>;
#   void:triples 823262567 .
#
# <http://rdfportal.org/ns/e41c369dbc6f14c727e106010ae4160f> void:property <http://purl.uniprot.org/core/submittedTo>;
#   void:triples 397885 .
#
# <http://rdfportal.org/ns/e49a478324d0ad7d428b67787a822431> void:property <http://www.w3.org/2004/02/skos/core#altLabel>;
#   void:triples 2624532 .
#
# <http://rdfportal.org/ns/ec4ea904d4bee2c74dc1dddc640c0852> void:property <http://purl.uniprot.org/core/citation>;
#   void:triples 307847817 .
#
# <http://rdfportal.org/ns/ee369adc3dfe2cf5deb26cab119f57bd> void:property <http://purl.uniprot.org/core/ecName>;
#   void:triples 42317186 .
#
# <http://rdfportal.org/ns/f254ba01ba90b96bbc8d6b9548449e1d> void:property <http://purl.uniprot.org/core/orfName>;
#   void:triples 232820563 .
#
# <http://rdfportal.org/ns/f349290ab579857aa79607b64c526ec3> void:property <http://purl.uniprot.org/core/interaction>;
#   void:triples 211953 .
#
# <http://rdfportal.org/ns/f480f83f48cf80539f21161eeb7e5d66> void:property <http://purl.uniprot.org/core/xeno>;
#   void:triples 107648 .
#
# <http://rdfportal.org/ns/f6449ce38048ee49928d73f74dcb06db> void:property <http://purl.uniprot.org/core/conflictingSequence>;
#   void:triples 348894 .
#
# <http://rdfportal.org/ns/f9410d56e44a45c00ca9b5758e53b344> void:property <http://purl.uniprot.org/core/range>;
#   void:triples 832102769 .
#
# <http://rdfportal.org/ns/fbadc53bd720db8ece063d46719b2288> void:property <http://purl.uniprot.org/core/recommendedName>;
#   void:triples 110031551 .
#
# <http://rdfportal.org/ns/fc2a825d72a59e1533e6895ecf1cf4c4> void:property <http://purl.uniprot.org/core/potentialSequence>;
#   void:triples 40298537 .
#
# <http://rdfportal.org/ns/ffca3c29c75c31aaac4817173d05e615> void:property <http://purl.uniprot.org/core/encodedIn>;
#   void:triples 5397386 .

# %%
rudof.read_service_description_str(dbcls_turtle)

# %% [markdown]
# And now we can get the information of the service description as before with:

# %%
service = rudof.get_service_description()
service_str = service.serialize(ServiceDescriptionFormat.Json)
print(f"Service description in JSON:\n{service_str}")
# Out:
# Service description in JSON:
# {
#   "default_dataset": {
#     "id": {
#       "Iri": "http://rdfportal.org/ns/root"
#     },
#     "default_graph": null,
#     "named_graphs": [
#       {
#         "id": {
#           "Iri": "http://rdfportal.org/ns/2c0544f688656cff12b9b69af828aaf3"
#         },
#         "name": "http://sparql.uniprot.org/uniprot",
#         "graphs": [
#           {
#             "id": {
#               "Iri": "http://rdfportal.org/ns/2c0544f688656cff12b9b69af828aaf3"
#             },
#             "triples": 53650641556,
#             "classes": 109,
#             "property_partition": [
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/8e414f07a2e4ea9f16e2e19f031b5e75"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#comment",
#                 "triples": 973868418
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/62576f2e248bfc495ae75cdfbb5c54c7"
#                 },
#                 "property": "http://purl.uniprot.org/core/group",
#                 "triples": 10784
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/c8c28693d8eb7e3eab2aee7cef9f5433"
#                 },
#                 "property": "http://purl.uniprot.org/core/publisher",
#                 "triples": 497
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/2e050cb3f2d0b4ae04c9b8fa323bbed2"
#                 },
#                 "property": "http://purl.uniprot.org/core/annotation",
#                 "triples": 1279738402
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/f480f83f48cf80539f21161eeb7e5d66"
#                 },
#                 "property": "http://purl.uniprot.org/core/xeno",
#                 "triples": 107648
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/71db477b038a1b177f363f10759bcf83"
#                 },
#                 "property": "http://purl.uniprot.org/core/shortName",
#                 "triples": 14883222
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/c516d97c6236172c3fb8e6185f3ac7e4"
#                 },
#                 "property": "http://purl.uniprot.org/core/measuredActivity",
#                 "triples": 9324
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/f9410d56e44a45c00ca9b5758e53b344"
#                 },
#                 "property": "http://purl.uniprot.org/core/range",
#                 "triples": 832102769
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/9caec961e050561b599cd1cbbed8940f"
#                 },
#                 "property": "http://purl.uniprot.org/core/reviewed",
#                 "triples": 245896765
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/083ab4eeef0ccf988cfb283883993cb3"
#                 },
#                 "property": "http://purl.uniprot.org/core/component",
#                 "triples": 833024
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/61e63b36d6c6cf1e4fec8b6756cc2d9c"
#                 },
#                 "property": "http://purl.uniprot.org/core/cdAntigenName",
#                 "triples": 1562
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/068006b84e2857758882a4f53a2eab10"
#                 },
#                 "property": "http://purl.uniprot.org/core/maximum",
#                 "triples": 133
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/4b2b2b11b83a7359dbd13842e77bb63c"
#                 },
#                 "property": "http://purl.uniprot.org/core/title",
#                 "triples": 792915
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/9f9640c3efd71e1282924456bea9dfd6"
#                 },
#                 "property": "http://purl.uniprot.org/core/version",
#                 "triples": 491793530
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/170298b996a3c141f37b8391ee59c2a2"
#                 },
#                 "property": "http://purl.uniprot.org/core/experiments",
#                 "triples": 107648
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/4a056f8f7893eab0f3a641d799fb8f6c"
#                 },
#                 "property": "http://purl.uniprot.org/core/certain",
#                 "triples": 20
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/2bec80fbe9ac367b95365c5be3ae88ec"
#                 },
#                 "property": "http://purl.uniprot.org/core/resolution",
#                 "triples": 192899
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/18a652bb46a871a9a49e68771866f00e"
#                 },
#                 "property": "http://purl.uniprot.org/core/alternativeName",
#                 "triples": 30510022
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/88212c04faf1ce4dbaffe0d7406e66b4"
#                 },
#                 "property": "http://purl.uniprot.org/core/locator",
#                 "triples": 506
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/d44817c74ca600eeb68ef2602449267d"
#                 },
#                 "property": "http://purl.uniprot.org/core/place",
#                 "triples": 2037
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/95eee82267f0862d03dc40808a5d0a3b"
#                 },
#                 "property": "http://purl.uniprot.org/core/scope",
#                 "triples": 287639429
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/9676f57279c20469836a34013b9b0d95"
#                 },
#                 "property": "http://purl.uniprot.org/core/translatedTo",
#                 "triples": 24697472
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/47554d446c30595fcadf11c2391bb149"
#                 },
#                 "property": "http://purl.uniprot.org/core/substitution",
#                 "triples": 423582
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/933fb3873deb5948d6227ebbc76b381e"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#object",
#                 "triples": 3949015008
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5b8e141a3892326b5fc78bedac06abf0"
#                 },
#                 "property": "http://purl.uniprot.org/core/pages",
#                 "triples": 470953
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/72a5e0b694ce7b43534edddbdbb4ec62"
#                 },
#                 "property": "http://biohackathon.org/resource/faldo#begin",
#                 "triples": 823263568
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/3cadc2b5ad1513633b9a8874a29f996a"
#                 },
#                 "property": "http://purl.uniprot.org/core/translatedFrom",
#                 "triples": 44817335
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ffca3c29c75c31aaac4817173d05e615"
#                 },
#                 "property": "http://purl.uniprot.org/core/encodedIn",
#                 "triples": 5397386
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e08bcbb8c55f1044faa72b9630ffb2a7"
#                 },
#                 "property": "http://purl.uniprot.org/core/measuredValue",
#                 "triples": 7575
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/af3c2a749ea5f03deb7af9d21c1e030e"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#subject",
#                 "triples": 3949014954
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/3b30c270b37a5e5a9351f13549bb5711"
#                 },
#                 "property": "http://purl.uniprot.org/core/fullName",
#                 "triples": 279499111
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/30c88dde57f59580f4c53229bb7b71d9"
#                 },
#                 "property": "http://www.w3.org/1999/02/22-rdf-syntax-ns#value",
#                 "triples": 245937954
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e49a478324d0ad7d428b67787a822431"
#                 },
#                 "property": "http://www.w3.org/2004/02/skos/core#altLabel",
#                 "triples": 2624532
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/20a0c7ca80e2312223dce7e8714294fc"
#                 },
#                 "property": "http://purl.uniprot.org/core/isolatedFrom",
#                 "triples": 18594853
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/df7b857ce5a78254ce9575e4635b8419"
#                 },
#                 "property": "http://purl.uniprot.org/core/modification",
#                 "triples": 62326
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/34c531be01f726da56829f3d7683ecea"
#                 },
#                 "property": "http://purl.uniprot.org/core/context",
#                 "triples": 270752851
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/73d577524ebb991c363dcb080d187fe0"
#                 },
#                 "property": "http://purl.uniprot.org/core/catalyticActivity",
#                 "triples": 41350799
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/fbadc53bd720db8ece063d46719b2288"
#                 },
#                 "property": "http://purl.uniprot.org/core/recommendedName",
#                 "triples": 110031551
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/4f1a498d17bcc716fa893702e2c09123"
#                 },
#                 "property": "http://purl.uniprot.org/core/fragment",
#                 "triples": 26089848
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/bc7ad2f65047b3c9703692097b99f653"
#                 },
#                 "property": "http://purl.uniprot.org/core/sequence",
#                 "triples": 246152080
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/bdaf9bb330fab1f8072a10cab7eb30ff"
#                 },
#                 "property": "http://purl.uniprot.org/core/erratum",
#                 "triples": 1192
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e1c26e06504e4ea5479432f1cd608a55"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#label",
#                 "triples": 257607494
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/841bc16e30ec6725efc7ac2f42583726"
#                 },
#                 "property": "http://purl.uniprot.org/core/measuredAffinity",
#                 "triples": 28197
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/1e7915487889f44c909ea4a363e41e96"
#                 },
#                 "property": "http://www.w3.org/2004/02/skos/core#prefLabel",
#                 "triples": 57617557
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/c720af7aeb9741f60850d4d1a193266b"
#                 },
#                 "property": "http://purl.uniprot.org/core/precursor",
#                 "triples": 515580
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/f6449ce38048ee49928d73f74dcb06db"
#                 },
#                 "property": "http://purl.uniprot.org/core/conflictingSequence",
#                 "triples": 348894
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/fc2a825d72a59e1533e6895ecf1cf4c4"
#                 },
#                 "property": "http://purl.uniprot.org/core/potentialSequence",
#                 "triples": 40298537
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/618f8acb14dc02b45642b064ce7d02de"
#                 },
#                 "property": "http://purl.uniprot.org/core/encodedBy",
#                 "triples": 233903911
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/825b8c255fdeb2f246be06616e2d9f23"
#                 },
#                 "property": "http://purl.uniprot.org/core/date",
#                 "triples": 897698
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/8f41e3be010c80057b655f44bb710e3a"
#                 },
#                 "property": "http://biohackathon.org/resource/faldo#location",
#                 "triples": 2864
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ee369adc3dfe2cf5deb26cab119f57bd"
#                 },
#                 "property": "http://purl.uniprot.org/core/ecName",
#                 "triples": 42317186
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/55021d5bd2e51a0fe9a21cb56c8adc25"
#                 },
#                 "property": "http://purl.uniprot.org/core/editor",
#                 "triples": 1378
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/a32878d63aab81d500155a79d70c5317"
#                 },
#                 "property": "http://purl.uniprot.org/core/oldMnemonic",
#                 "triples": 204115
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/7925d62c90a344d160df6c45128bfdd7"
#                 },
#                 "property": "http://biohackathon.org/resource/faldo#reference",
#                 "triples": 1429924072
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/b9f9966cc114e1c04610308685406e70"
#                 },
#                 "property": "http://www.w3.org/2002/07/owl#sameAs",
#                 "triples": 107963
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/3b4bd27369d71a1149bf923300aa2076"
#                 },
#                 "property": "http://purl.uniprot.org/core/md5Checksum",
#                 "triples": 245896765
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/bcea41f57b82243eded2dfbe1812c4e9"
#                 },
#                 "property": "http://purl.uniprot.org/core/created",
#                 "triples": 245896765
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/52df97376a01c0ce527f09ead904dd86"
#                 },
#                 "property": "http://purl.org/dc/terms/identifier",
#                 "triples": 391142
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/342538c67f9b0425996a043680c867ba"
#                 },
#                 "property": "http://purl.uniprot.org/core/author",
#                 "triples": 4825979
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/967b07323b82564925af44490c419676"
#                 },
#                 "property": "http://purl.uniprot.org/core/complete",
#                 "triples": 419059
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/cc951791e4f1e902a6af2e35963df50b"
#                 },
#                 "property": "http://purl.uniprot.org/core/domain",
#                 "triples": 1063928
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/d96c532176e37f7ec1767b0d6314a425"
#                 },
#                 "property": "http://purl.uniprot.org/core/mnemonic",
#                 "triples": 245896765
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/bfb28b9a8ff856005188b5aa5b47d49a"
#                 },
#                 "property": "http://purl.uniprot.org/core/allergenName",
#                 "triples": 866
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/dbb3f0be1a239cd85a77cce126815312"
#                 },
#                 "property": "http://purl.uniprot.org/core/name",
#                 "triples": 581698
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/507a217b1480ff2a66100ff4bae1f9f2"
#                 },
#                 "property": "http://purl.uniprot.org/core/locatedOn",
#                 "triples": 306728413
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/0f2783d303c00f60fb2fd6fef47313f2"
#                 },
#                 "property": "http://biohackathon.org/resource/faldo#position",
#                 "triples": 1429911576
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/52628fe36cbb0000db0f7532f9e8de6d"
#                 },
#                 "property": "http://purl.uniprot.org/core/volume",
#                 "triples": 476315
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/2442899b49990ee181f832da05008f24"
#                 },
#                 "property": "http://www.w3.org/2000/01/rdf-schema#seeAlso",
#                 "triples": 2985734039
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/f254ba01ba90b96bbc8d6b9548449e1d"
#                 },
#                 "property": "http://purl.uniprot.org/core/orfName",
#                 "triples": 232820563
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/15088098515de2f4c96fe17ccda0d7a3"
#                 },
#                 "property": "http://purl.uniprot.org/core/measuredError",
#                 "triples": 1231
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/6b829ca21c560f902d93bacc037d2fd9"
#                 },
#                 "property": "http://purl.uniprot.org/core/internationalNonproprietaryName",
#                 "triples": 28
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/d8c9ac45be9f00a68e8afb96c2a48204"
#                 },
#                 "property": "http://purl.uniprot.org/core/mass",
#                 "triples": 264858724
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5c3da1d6bf9c8615e9b623e96179fd7b"
#                 },
#                 "property": "http://purl.uniprot.org/core/modified",
#                 "triples": 491793530
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/4ad8811262e203bb17634a1cb30d8725"
#                 },
#                 "property": "http://purl.uniprot.org/core/submittedName",
#                 "triples": 138960067
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e2d88cf45c27d23bba9638e9bc26a3ac"
#                 },
#                 "property": "http://biohackathon.org/resource/faldo#end",
#                 "triples": 823262567
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/26ab55f3245fe4eb71671fe3e75fdf41"
#                 },
#                 "property": "http://biohackathon.org/resource/faldo#possiblePosition",
#                 "triples": 355
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/8456cffdaade2f214ba2ef68f8b1f6e2"
#                 },
#                 "property": "http://purl.uniprot.org/core/participant",
#                 "triples": 212168
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/1e4528689699198cef078e048c9b7824"
#                 },
#                 "property": "http://purl.uniprot.org/core/frameshift",
#                 "triples": 12
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5fa9757cc6e5c0b69b71935c1fb1915f"
#                 },
#                 "property": "http://purl.uniprot.org/core/locusName",
#                 "triples": 5129001
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ec4ea904d4bee2c74dc1dddc640c0852"
#                 },
#                 "property": "http://purl.uniprot.org/core/citation",
#                 "triples": 307847817
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e41c369dbc6f14c727e106010ae4160f"
#                 },
#                 "property": "http://purl.uniprot.org/core/submittedTo",
#                 "triples": 397885
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ce7c56b471b5b23d22208c8acf94f053"
#                 },
#                 "property": "http://purl.uniprot.org/core/institution",
#                 "triples": 1483
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/656ae83c04f0ff3fcea229b695f12246"
#                 },
#                 "property": "http://purl.uniprot.org/core/basedOn",
#                 "triples": 41189
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e171acb5096ce05b7cc6f02e36c87523"
#                 },
#                 "property": "http://purl.uniprot.org/core/transcribedFrom",
#                 "triples": 24662835
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/f349290ab579857aa79607b64c526ec3"
#                 },
#                 "property": "http://purl.uniprot.org/core/interaction",
#                 "triples": 211953
#               }
#             ],
#             "class_partition": [
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/778fcf5ab0eaaa4a433d37dc85f8785b"
#                 },
#                 "class": "http://purl.uniprot.org/core/Domain_Extent_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e5142fb21a1fc831fce9423201a60e85"
#                 },
#                 "class": "http://purl.uniprot.org/core/Observation_Citation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/720426e84c53acc699cd922a04923ebf"
#                 },
#                 "class": "http://purl.uniprot.org/core/Ribosomal_Frameshifting"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/07a56ccb0233f7943db8dc74583e12cd"
#                 },
#                 "class": "http://purl.uniprot.org/core/Non-standard_Residue_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/3946c1ca2deadc7cabb50c5ac897fbde"
#                 },
#                 "class": "http://purl.uniprot.org/core/Toxic_Dose_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/a6219df16a8b6363231acf5b2d86b7f4"
#                 },
#                 "class": "http://purl.uniprot.org/core/Simple_Sequence"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/b07af80049c3c19618ae9216b3ae4719"
#                 },
#                 "class": "http://purl.uniprot.org/core/Electronic_Citation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/0d8747a3d8e14f62a8d1bd7847e2fcb9"
#                 },
#                 "class": "http://purl.uniprot.org/core/Book_Citation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/57b2581646ca636f0eaa6dc890cea966"
#                 },
#                 "class": "http://purl.uniprot.org/core/Sequence_Conflict_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/b1b2dd0f458a93bd96769bb645d85b15"
#                 },
#                 "class": "http://purl.uniprot.org/core/Transposon"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/42c187547e5340bce5d08a649ce5f90b"
#                 },
#                 "class": "http://purl.uniprot.org/core/Non_Self_Interaction"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/bc3f2ee5002ffbffa170f40c2508914a"
#                 },
#                 "class": "http://purl.uniprot.org/core/Erroneous_Gene_Model_Prediction_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/f7f645337b89d7970ab12904c57c065e"
#                 },
#                 "class": "http://purl.uniprot.org/core/Frameshift_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ed291b1db56716194ce40d0636b3a0e0"
#                 },
#                 "class": "http://purl.uniprot.org/core/Function_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/27923baebe3698e74394f18bb2ba8835"
#                 },
#                 "class": "http://purl.uniprot.org/core/Patent_Citation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/21c55b48b516ba111107a7f98224d9b3"
#                 },
#                 "class": "http://purl.uniprot.org/core/Caution_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/db32ea08cba8edd3c3c3b871423edc44"
#                 },
#                 "class": "http://purl.uniprot.org/core/Strain"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/fac5206db3a11006b533fba7b9860740"
#                 },
#                 "class": "http://purl.uniprot.org/core/Alternative_Initiation_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/efb479ebf2ec56f55c2e7c29cf6aca8c"
#                 },
#                 "class": "http://purl.uniprot.org/core/Journal_Citation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/cbbb10874ac0db9cca62be3cfbfa4770"
#                 },
#                 "class": "http://purl.uniprot.org/core/Transmembrane_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/92cfd4f11e37a86c711fdb868fefe075"
#                 },
#                 "class": "http://purl.uniprot.org/core/Active_Site_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/3021449d18fe96d83094a155a1794c3c"
#                 },
#                 "class": "http://purl.uniprot.org/core/PH_Dependence_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/a78e2d3050c39459f1c46f142db32aaf"
#                 },
#                 "class": "http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/6ec746d5dd279fbfbd30c1ce9f7c012a"
#                 },
#                 "class": "http://purl.uniprot.org/core/Binding_Site_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/301c9085d0b1f16dcc4efcbbcd8bbe4a"
#                 },
#                 "class": "http://purl.uniprot.org/core/Resource"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/c585913fda0da7397ed9e0ae838b5aef"
#                 },
#                 "class": "http://purl.uniprot.org/core/Pharmaceutical_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e92b4496513eca1edbbfbf84d5621a71"
#                 },
#                 "class": "http://purl.uniprot.org/core/Pathway_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e73a7f8415984899bda09dc9b9ff0fbd"
#                 },
#                 "class": "http://purl.uniprot.org/core/Activity_Regulation_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/2d4edfffa9d1a07520997076cc357014"
#                 },
#                 "class": "http://purl.uniprot.org/core/Tissue"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/4781edb33ffab1dec2478c315bdd7510"
#                 },
#                 "class": "http://purl.uniprot.org/core/Part"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/dd83198f305a3359b0119351a3a480f1"
#                 },
#                 "class": "http://purl.uniprot.org/core/Protein"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5319bea414da9e86cfe376c7bcd27eb6"
#                 },
#                 "class": "http://biohackathon.org/resource/faldo#OneOfPosition"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/fa7e1b39e9359d64a44d7544f136fa1c"
#                 },
#                 "class": "http://purl.uniprot.org/core/Polymorphism_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ef012a1166375bd7721ed56d7edb370e"
#                 },
#                 "class": "http://purl.uniprot.org/core/Compositional_Bias_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/3da0ea0d5d39f2cc632c7dc8cb451404"
#                 },
#                 "class": "http://purl.uniprot.org/core/Developmental_Stage_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/1ffa5968db4d2538e2f294e8fe028348"
#                 },
#                 "class": "http://purl.uniprot.org/core/RNA_Editing_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/1f7b3a944599166b377bd1833c93c046"
#                 },
#                 "class": "http://biohackathon.org/resource/faldo#InRangePosition"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/dac16526e2f104c06cc7966dfbb450a9"
#                 },
#                 "class": "http://purl.uniprot.org/core/Coiled_Coil_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5ed84ac81a5ad6530c2ed530ad2b9b38"
#                 },
#                 "class": "http://purl.uniprot.org/core/Modified_Residue_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/0f6b07db53c4dfc3736eb65e38170a5c"
#                 },
#                 "class": "http://purl.uniprot.org/core/Gene"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/a9842f33ba1b20291f832c85e0b60e4d"
#                 },
#                 "class": "http://purl.uniprot.org/core/Helix_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5c2c7ecf2a035e0d4bda83b90b3fc2e1"
#                 },
#                 "class": "http://purl.uniprot.org/core/Mutagenesis_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/bbd56de9aed5d3d260c9df759fd352b4"
#                 },
#                 "class": "http://purl.uniprot.org/core/Kinetics_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/eec3bf688a52011540a5c1b9482bcece"
#                 },
#                 "class": "http://purl.uniprot.org/core/Peptide_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e23065c09fa93631dbaa90b9eb7ef552"
#                 },
#                 "class": "http://purl.uniprot.org/core/Structure_Resource"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5b7c5a8e899d53716c02345839ff825c"
#                 },
#                 "class": "http://purl.uniprot.org/core/Chain_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ff3cd39a9e77fa8ad9af1c97abedfdc0"
#                 },
#                 "class": "http://purl.uniprot.org/core/Self_Interaction"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/2f8d4a9168912aebcc1e8b615454425f"
#                 },
#                 "class": "http://purl.uniprot.org/core/Beta_Strand_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/7164b05756c17545d28fe0ec374b0f66"
#                 },
#                 "class": "http://purl.uniprot.org/core/Repeat_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/a96ffd968b8948cec240a4df3c9021a3"
#                 },
#                 "class": "http://purl.uniprot.org/core/Unknown_Sequence"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/525efedd2a4e6236c139ee851e67cf09"
#                 },
#                 "class": "http://purl.uniprot.org/core/External_Sequence"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/664e33c85a9d30a31dc0b4e36287c243"
#                 },
#                 "class": "http://purl.uniprot.org/core/Erroneous_Termination_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/4fa652c4e7fa112fd7da52ade68f30c1"
#                 },
#                 "class": "http://purl.uniprot.org/core/Thesis_Citation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/2d7bceb87eae338b687e018ceb0fc2e3"
#                 },
#                 "class": "http://purl.uniprot.org/core/Propeptide_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/b87320c87c6a0b5ab6ad9af0f1538042"
#                 },
#                 "class": "http://purl.uniprot.org/core/Site_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/09e287d166193b1bb334c1ee918e6734"
#                 },
#                 "class": "http://purl.uniprot.org/core/Non-adjacent_Residues_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5a984681ffc9a7aadf2d765d81bbb622"
#                 },
#                 "class": "http://purl.uniprot.org/core/Disease_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e1d6dae915684ca92380ae7e1ff8f68d"
#                 },
#                 "class": "http://purl.uniprot.org/core/Transcript_Resource"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/1164fc1f249b193fdf35ca26851f2976"
#                 },
#                 "class": "http://purl.uniprot.org/core/Temperature_Dependence_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e301855029e71a0f26d4bd2c74b62169"
#                 },
#                 "class": "http://purl.uniprot.org/core/Erroneous_Initiation_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/364460df27c931987e770ec9206a3f31"
#                 },
#                 "class": "http://purl.uniprot.org/core/Mass_Spectrometry_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/f84f61cc6f5d94c8abf3bfe5091d3d95"
#                 },
#                 "class": "http://purl.uniprot.org/core/Zinc_Finger_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/0d8efbfb22568bc3e264ed3d915985bd"
#                 },
#                 "class": "http://purl.uniprot.org/core/Nucleotide_Resource"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/adc311169826ac9b05c8d3a7d182df51"
#                 },
#                 "class": "http://purl.uniprot.org/core/Natural_Variant_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e5115f22a21fab8c9cd02c59795cf812"
#                 },
#                 "class": "http://purl.uniprot.org/core/Signal_Peptide_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/7f8df1dac83000ceb57f633db3d150f5"
#                 },
#                 "class": "http://purl.uniprot.org/core/Disulfide_Bond_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/4193abffbb00679daaeb6af0ea8ff9bb"
#                 },
#                 "class": "http://purl.uniprot.org/core/Plasmid"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/b6681d40b12e3ca4017252a5f704193a"
#                 },
#                 "class": "http://purl.uniprot.org/core/Sequence_Caution_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/c503969ca88a1e4ead279c8a1f6f095e"
#                 },
#                 "class": "http://purl.uniprot.org/core/Transit_Peptide_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e4388631b6677b64f13ad3911fb413b3"
#                 },
#                 "class": "http://purl.uniprot.org/core/Disruption_Phenotype_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/37254c488eda87d6dbbf001af12bb136"
#                 },
#                 "class": "http://purl.uniprot.org/core/Induction_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/12056644897611483340bb2caf6f8c9c"
#                 },
#                 "class": "http://purl.uniprot.org/core/Glycosylation_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/91dc967871d9c4844ca51f83cb7be6db"
#                 },
#                 "class": "http://purl.uniprot.org/core/Topological_Domain_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/6b43b12d10bd5d2feb39807e7fcdffff"
#                 },
#                 "class": "http://purl.uniprot.org/core/Interaction"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/f2340e94b4fe1713af9f04481f07f6ea"
#                 },
#                 "class": "http://purl.uniprot.org/core/Biotechnology_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/74c1f7ca6b33ceb0e197a3e73eed36dc"
#                 },
#                 "class": "http://purl.uniprot.org/core/Catalytic_Activity_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/c6dc1553317afe855fc205d6ae4ceeb3"
#                 },
#                 "class": "http://purl.uniprot.org/core/Cross-link_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/91a3f42d0c558121046b72dde99fa7d4"
#                 },
#                 "class": "http://purl.uniprot.org/core/Turn_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/be04539c845200b6daee3b1ec6004420"
#                 },
#                 "class": "http://purl.uniprot.org/core/Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/a220fa341d3ec629c6eac53fa5eff359"
#                 },
#                 "class": "http://biohackathon.org/resource/faldo#Position"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e6a5c1505d851d092a2b98bfbb478b1f"
#                 },
#                 "class": "http://purl.uniprot.org/core/Initiator_Methionine_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/830582048b50b43603995dd1ba34bb75"
#                 },
#                 "class": "http://purl.uniprot.org/core/Intramembrane_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/15eae2eef1f2102a49aee9ac17ce0741"
#                 },
#                 "class": "http://purl.uniprot.org/core/Subcellular_Location_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/6b235fca679778b8c01df8e7973ef142"
#                 },
#                 "class": "http://purl.uniprot.org/core/Domain_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/d011e2e479d98a040eff9671f22e98fc"
#                 },
#                 "class": "http://purl.uniprot.org/core/Similarity_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/9beceea72e6dc07f81ab3801c77f7ee4"
#                 },
#                 "class": "http://purl.uniprot.org/core/Subunit_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/b4ba4cb41b70a07ec04b0af7db79d508"
#                 },
#                 "class": "http://purl.uniprot.org/core/Modified_Sequence"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ddfac0291c8dd73b330cf2044c2ec8c4"
#                 },
#                 "class": "http://purl.uniprot.org/core/Alternative_Sequence_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/dc5977b71a8df0e958d6552b651d35b7"
#                 },
#                 "class": "http://biohackathon.org/resource/faldo#Region"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5c449aecd03bf20abafedd46cd5310d0"
#                 },
#                 "class": "http://purl.uniprot.org/core/Sequence_Uncertainty_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/e973c376c96895910750a220b0bef373"
#                 },
#                 "class": "http://purl.uniprot.org/core/Participant"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/baf433a60317a922894c49dd57e85178"
#                 },
#                 "class": "http://purl.uniprot.org/core/Nucleotide_Binding_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/42765e3dfc44d679373690e98bae44bb"
#                 },
#                 "class": "http://purl.uniprot.org/core/Structured_Name"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/70c0554e7fd55f4e870cebaa10aa1463"
#                 },
#                 "class": "http://purl.uniprot.org/core/Lipidation_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/765417b5049617b5174d03c855cfeb63"
#                 },
#                 "class": "http://purl.uniprot.org/core/Alternative_Splicing_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/84bb171399ae5634ef516e55c871dc3d"
#                 },
#                 "class": "http://purl.uniprot.org/core/Absorption_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/afad339ecc918819b698bf7eebf593c5"
#                 },
#                 "class": "http://biohackathon.org/resource/faldo#ExactPosition"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5d30abc467b3592da7541fd658457f8b"
#                 },
#                 "class": "http://purl.uniprot.org/core/PTM_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/1e730487a45ea286639e131b581bac17"
#                 },
#                 "class": "http://purl.uniprot.org/core/Non-terminal_Residue_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/eb74200e1b8a382112584b18368c88a4"
#                 },
#                 "class": "http://purl.uniprot.org/core/Cofactor_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/1274ff826cde5f398df6e8c72841e211"
#                 },
#                 "class": "http://purl.uniprot.org/core/Alternative_Promoter_Usage_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/a6b136b63ec0f96d5c4c1b93a4e8ae29"
#                 },
#                 "class": "http://purl.uniprot.org/core/Citation_Statement"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/235b4f80c427af2ad8373b1fd201a95b"
#                 },
#                 "class": "http://purl.uniprot.org/core/Allergen_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/c5a2e27eaecd0e20dda7f3c0f4049712"
#                 },
#                 "class": "http://purl.uniprot.org/core/Motif_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/ba956b5151fe41467144242571241533"
#                 },
#                 "class": "http://purl.uniprot.org/core/Redox_Potential_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/b1be2c885b12d1d451dea22a08caa9de"
#                 },
#                 "class": "http://purl.uniprot.org/core/Tissue_Specificity_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/6e15244cd9a66085723e113fbc342c66"
#                 },
#                 "class": "http://purl.uniprot.org/core/Erroneous_Translation_Annotation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/5a293a0a51a9680133be873f188f471d"
#                 },
#                 "class": "http://purl.uniprot.org/core/Submission_Citation"
#               },
#               {
#                 "id": {
#                   "Iri": "http://rdfportal.org/ns/81641d9a751d403e4fcac2d06d6aafaf"
#                 },
#                 "class": "http://purl.uniprot.org/core/Region_Annotation"
#               }
#             ]
#           }
#         ]
#       }
#     ]
#   },
#   "prefixmap": {
#     "fn": "http://www.w3.org/2005/xpath-functions#",
#     "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
#     "void": "http://rdfs.org/ns/void#",
#     "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
#     "sd": "http://www.w3.org/ns/sparql-service-description#",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "owl": "http://www.w3.org/2002/07/owl#",
#     "sesame": "http://www.openrdf.org/schema/sesame#",
#     "rdf4j": "http://rdf4j.org/schema/rdf4j#"
#   }
# }
